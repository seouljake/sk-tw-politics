# %%
import pandas as pd
import numpy as np

# %%
import urllib.parse
from bs4 import BeautifulSoup

# %%
import requests
import brotli

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %% [markdown]
# # import sk & tw politician test data

# %%
filein_path = "../../../data/data_wikis/1 - politician data for test scraping/"

# %%
sktest = pd.read_excel(filein_path+"sk_testset.xlsx")

# %%
sktest.shape
# Out:
# (10114, 23)

# %%
sktest["HasNamuWiki"]=np.nan

# %%
#twtest = pd.read_excel(filein_path+"tw_testset.xlsx")

# %%
#twtest.shape

# %% [markdown]
# # scrape namuwiki for sk politicians

# %%
test = sktest[0:2]

# %%
test
# Out:
#   Name_Native Name_Chinese  Birthdate Sex  Age ElectionCategory_Native  \
# 0         가세로          賈世魯   19550815   남   58              구·시·군의 장선거
# 1         가창현          賈昌鉉   19550315   남   59             구·시·군의회의원선거
#
#    ElectionDate    Position L1_Division L2_Division  ...  CandidateStatus  \
# 0      20140604       Chief        충청남도         태안군  ...               등록
# 1      20140604  Legislator        충청남도         태안군  ...               등록
#
#   WonElection VoteCount VotePercent IncumbentStatus  Occupation  \
# 0           0       NaN         NaN             NaN         정당인
# 1           0       NaN         NaN             NaN         정치인
#
#                  Education                    Career1  \
# 0          단국대학교 대학원 행정학박사  (전)박근혜대통령후보 대선 서산.태안총괄본부장
# 1  서산농림고등학교 졸업(현 서산중앙고등학교)               (전)태안군환경산림과장
#
#                      Career2 HasNamuWiki
# 0  (현)"박근혜를 사랑하는 모임" 전국 상임고문         NaN
# 1               (전)태안군사회복지과장         NaN
#
# [2 rows x 24 columns]

# %%
url_stem = "https://namu.wiki"

p_error_name = "data-v-1ac09f2e"
p_error_text = "해당 문서를 찾을 수 없습니다."

# %%
# more complicated request header

request_headers1 = {"authority": "namu.wiki",
                   "method": "GET",
                   "path":"/w/%EA%B0%80%EC%84%B8%EB%A1%9C",
                   "scheme":"https",
                   "accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
                   "accept-encoding":"gzip, deflate, br",
                   "accept-language":"en-US,en;q=0.9,ko;q=0.8",
                   "cache-control":"max-age=0",
                   "cookie":cookie_string,
                   "referer": "http://localhost:8888/", # this changed
                   "sec-ch-ua": '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
                   "sec-ch-ua-mobile":"?0",
                   "sec-ch-ua-platform":"Windows",
                   "sec-fetch-dest":"document",
                   "sec-fetch-mode":"navigate",
                   "sec-fetch-site":"same-origin",
                   "sec-fetch-user":"?1",
                   "upgrade-insecure-requests":"1",
                   "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}

# %%
# more complicated request header

request_headers2 = {"accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
                   "accept-encoding":"gzip, deflate, br",
                   "accept-language":"en-US,en;q=0.9,ko;q=0.8",
                   "cache-control":"max-age=0",
                   "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}

# %%
# strategies

# 1. pass cookies? receive cookies?
# 2. block javascript?


# get namuwiki using requests
for index,p in test.iterrows():
    
    # construct headers
    headers = {}
    #headers = request_headers1
    #headers = request_headers2

    
    # construct cookies
    cookies = {}
    
    # construct url
    url= url_stem+"/w/"+urllib.parse.quote(p.Name_Native.encode("utf-8"))
    
    print("==================================================\n")
    print(p.Name_Native)
    print(url_stem)
    print(urllib.parse.quote(p.Name_Native.encode("utf-8")))
    print(url)
    
    
    # request with session
    if(True):
    
        # request session
        s = requests.Session()
        y = s.get(url_stem,headers=headers)
    
        y_cookies = dict(y.cookies)

        print(y.status_code)
        #print(y.headers)
        print(y_cookies)

    
        # request url
        x = s.get(url,headers=headers)
        
        x_cookies = dict(x.cookies)


        print(x.status_code)
        #print(x.headers)
        print(x_cookies)

    
    # request without session
    else:

        # request url
        x = requests.get(url,headers=headers,cookies=cookies)
        
        x_cookies = dict(x.cookies)

        print(x.status_code)
        #print(x.headers)
        print(x_cookies)


        
    
    # decode and save response as html
    if(False):
        
        # decode request object - which was coded using br (brotli algorithm)
        content = brotli.decompress(x.content)
    
        #print(content)

        # save output as an html file
        fout = open("test_"+p.Name_Native+".html","w")
        #fout.write(x.content.decode("utf-8"))
        fout.write(content.decode("utf-8"))
        fout.close()

        # convert to html using BeautifulSoup 

        soup = BeautifulSoup(content.decode("utf-8"),"html.parser")
        html = soup.prettify("utf-8")
        #print(html)
# Out:
# ==================================================
#
# 가세로
# https://namu.wiki
# %EA%B0%80%EC%84%B8%EB%A1%9C
# https://namu.wiki/w/%EA%B0%80%EC%84%B8%EB%A1%9C
# 403
# {'__cf_bm': '6w58kzXyuC0rU0462mA5w3iqiK7nq6pYq1VywOnThMs-1658281700-0-AQbTylNwkRykaSIX9Z/eV/5Gmy6gmoyWqRcWpLOK9Ow63WhxzyOCpcKEYUggOVmwqhWtg9XkmCUnXEFy9Th1TKI='}
# 403
# {}
# ==================================================
#
# 가창현
# https://namu.wiki
# %EA%B0%80%EC%B0%BD%ED%98%84
# https://namu.wiki/w/%EA%B0%80%EC%B0%BD%ED%98%84
# 403
# {'__cf_bm': 'ke.bDAHxVbJ9xSI62QQOrl.3Y0CIVI1VfPSaT6y5qcQ-1658281700-0-ATX/HxR2N9nUHvpHWmeysHi099o53FJydNzCrCrtqM8RUYdVwB7aB6LNF81gDsdFnqt9YPHO97bvLEYnVDKALWA='}
# 403
# {}

# %% [markdown]
# # request with selenium

# %%
# instantiate selenium webdriver
service = Service(executable_path=ChromeDriverManager().install())

# scrape namuwiki using selenium
for index,p in test.iterrows():
    
    # construct url
    url= url_stem+"/w/"+urllib.parse.quote(p.Name_Native.encode("utf-8"))
    
    # reset content & has_content_flag
    has_content_flag = True
    content=""

    # request url using selenium webdriver
    driver = webdriver.Chrome(service=service)
    driver.get(url)
    
    # check if page has content
    elements = driver.find_elements(By.TAG_NAME, 'p')
    
    for e in elements:
        if(e.text==p_error_text):
            has_content_flag = False
            
    if(has_content_flag):
        content = driver.page_source

    # close webdriver
    driver.quit()

    # save content
    if(has_content_flag):

        # save output as an html file
        fout = open("seleniumtest_"+p.Name_Native+".html","w",encoding="utf-8")
        fout.write(content)
        fout.close()
        
        print(index,p.Name_Native,"Number of <p> elements:",len(elements),"Has Content")
        
    else:
        print(index,p.Name_Native,"Number of <p> elements:",len(elements),"Empty")



    
    #cookie = {l["name"]:l["value"] for l in driver.get_cookies()}
    #print(cookie)
# Out:
# 0 가세로 Number of <p> elements: 4 Has Content
# 1 가창현 Number of <p> elements: 5 Empty

# %%
content
# Out:
# '<html><head><title>가세로 - 나무위키</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, width=device-width"><meta data-n-head="ssr" http-equv="x-ua-compatible" content="ie=edge"><meta data-n-head="ssr" name="generator" content="the seed"><meta data-n-head="ssr" name="mobile-web-app-capable" content="yes"><meta data-n-head="ssr" name="application-name" content="나무위키"><meta data-n-head="ssr" name="msapplication-tooltip" content="나무위키"><meta data-n-head="ssr" name="msapplication-starturl" content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8"><meta data-n-head="ssr" name="robots" content="max-image-preview:large"><meta data-n-head="ssr" name="theme-color" content="#008275"><meta data-n-head="ssr" name="googlebot" content="noarchive"><link data-n-head="ssr" rel="canonical" href="https://namu.wiki/w/%EA%B0%80%EC%84%B8%EB%A1%9C"><link data-n-head="ssr" rel="search" type="application/opensearchdescription+xml" title="나무위키" href="/opensearch.xml"><link data-n-head="ssr" rel="copyright" href="//creativecommons.org/licenses/by-nc-sa/2.0/kr/"><link data-n-head="ssr" rel="icon" href="/favicon.svg" sizes="any" type="image/svg+xml"><link data-n-head="ssr" rel="icon" href="/favicon-32.png" sizes="32x32" type="image/png"><link data-n-head="ssr" rel="icon" href="/favicon-192.png" sizes="192x192" type="image/png"><link data-n-head="ssr" rel="apple-touch-icon" href="/img/apple_icon.png"><script data-n-head="ssr" async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><link rel="preload" href="/skins/senkawa/manifest.a5223e5328d6eee17b4e.js" as="script"><link rel="preload" href="/skins/senkawa/vendor.9ba409b44980ad49e50a.js" as="script"><link rel="preload" href="/skins/senkawa/155.6a00ac00a52fad1984c5.css" as="style"><link rel="preload" href="/skins/senkawa/main.557b4662edfcc9734bcd.css" as="style"><link rel="preload" href="/skins/senkawa/main.557b4662edfcc9734bcd.js" as="script"><link rel="stylesheet" href="/skins/senkawa/155.6a00ac00a52fad1984c5.css"><link rel="stylesheet" href="/skins/senkawa/main.557b4662edfcc9734bcd.css"><script async="" src="/cdn-cgi/bm/cv/669835187/api.js"></script><style type="text/css">.resize-observer[data-v-b329ee4c]{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;border:none;background-color:transparent;pointer-events:none;display:block;overflow:hidden;opacity:0}.resize-observer[data-v-b329ee4c] object{display:block;position:absolute;top:0;left:0;height:100%;width:100%;overflow:hidden;pointer-events:none;z-index:-1}</style><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2022071401.js" async=""></script><link rel="preload" href="https://adservice.google.com.tw/adsid/integrator.js?domain=namu.wiki" as="script"><script type="text/javascript" src="https://adservice.google.com.tw/adsid/integrator.js?domain=namu.wiki"></script><link rel="preload" href="https://adservice.google.com/adsid/integrator.j ...
