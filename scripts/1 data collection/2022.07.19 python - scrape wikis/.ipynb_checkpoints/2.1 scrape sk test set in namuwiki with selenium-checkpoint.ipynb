# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %%
import os
import urllib.parse

# %%
import requests
import brotli
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
filein_path = "../../../data/data_wikis/1 - politician data for test scraping/"

# %%
fileout_path = "../../../data/data_wikis/2.1 - sk namuwiki scraping test/"

# %%
logfile_name = "_seleniumtest_log.txt"

# %% [markdown]
# # import sk & tw politician test data

# %%
sktest = pd.read_excel(filein_path+"sk_testset.xlsx")

# %%
sktest.shape
# Out:
# (9960, 24)

# %%
# sktest["URL_NamuWiki"]=np.nan

# %%
sktest[3000:3100]
# Out:
#      Name_Native Name_Chinese  Birthdate Sex  Age ElectionCategory_Native  \
# 3000         문병원          文炳元   19570507   남   57              광역의원비례대표선거
# 3001         문병호          文炳浩   19591227   남   56                  국회의원선거
# 3002         문병화          文炳華   19620404   남   52             구·시·군의회의원선거
# 3003         문병훈          文柄勳   19790315   남   35             구·시·군의회의원선거
# 3004         문보현          文普玄   19650519   남   50                  국회의원선거
# 3005         문복란          文福蘭   19560601   여   58             구·시·군의회의원선거
# 3006         문봉도          文奉道   19650505   남   49             구·시·군의회의원선거
# 3007         문봉선          文峰仙   19620310   여   52             구·시·군의회의원선거
# 3008         문상모          文鋿模   19690202   남   45               시·도의회의원선거
# 3009         문상선          文相宣   19670404   남   47             구·시·군의회의원선거
# 3010         문상필          文祥弼   19661015   남   47               시·도의회의원선거
# 3011         문석완          文錫完   19570914   남   56              구·시·군의 장선거
# 3012         문석주          文碩柱   19620827   남   51               시·도의회의원선거
# 3013         문석주          文錫周   19651212   남   48             구·시·군의회의원선거
# 3014         문석진          文錫珍   19550710   남   58              구·시·군의 장선거
# 3015         문석호          文錫鎬   19470224   남   67                  교육의원선거
# 3016         문선화          文宣化   19751020   여   38              기초의원비례대표선거
# 3017         문성기          文成起   19480105   남   66             구·시·군의회의원선거
# 3018         문성덕          文性德   19610406   남   53             구·시·군의회의원선거
# 3019         문성욱          文成旭   19550518   남   59             구·시·군의회의원선거
# 3020         문성원          文成元   19690325   남   45             구·시·군의회의원선거
# 3021         문성주          文聖柱   19600626   남   53             구·시·군의회의원선거
# 3022         문수곤          文壽坤   19511124   남   62             구·시·군의회의원선거
# 3023         문순규          文焞圭   19721224   남   41             구·시·군의회의원선거
# 3024         문순석          文淳錫   19530513   남   61             구·시·군의회의원선거
# 3025         문승식          文勝植   19620630   남   51             구·시·군의회의원선거
# 3026         문신호          文新昊   19520517   남   62             구·시·군의회의원선거
# 3027         문쌍수          文雙守   19530913   남   60             구·시·군의회의원선거
# 3028         문양오          文暘五   19590226   남   55             구·시·군의회의원선거
# 3029         문영경          文英卿   19650225   여   49             구·시·군의회의원선거
# 3030         문영근          文英根   19620813   남   51             구·시·군의회의원선거
# 3031         문영남          文永男   19790616   남   34             구·시·군의회의원선거
# 3032         문영두          文榮斗   19620829   남   51             구·시·군의회의원선거
# 3033         문영미          文英美   19591130   여   54             구·시·군의회의원선거
# 3034         문영미          文英美   19660516   여   48             구·시·군의회의원선거
# 3035         문영민          文永敏   19501226   남   63               시·도의회의원선거
# 3036         문영식          文英植   19570220   여   57              기초의원비례대표선거
# 3083         민경선          閔敬善   19710206   남   43               시·도의회의원선거
# 3084         민경술          閔庚述   19490201   남   65             구·시·군의회의원선거
# 3085         민경욱          閔庚旭   19630617   남   52                  국회의원선거
# 3086         민경원          閔卿圓   19641001   여   51              비례대표국회의원선거
# 3087         민경자          閔敬子   19640520   여   50             구·시·군의회의원선거
# 3088         민경철          閔庚喆   19620112   남   52               시·도의회의원선거
# 3089         민경태          閔庚泰   19610130   남   53             구·시·군의회의원선거
# 3090         민광석          閔光席   19590220   남   55             구·시·군의회의원선거
# 3091         민국열          閔國烈   19690518   남   45             구·시·군의회의원선거
# 3092         민근홍          閔根泓   19650721   남   48               시·도의회의원선거
# 3093         민맹호          閔孟鎬   19460816   남   67             구·시·군의회의원선거
# 3094         민병대          閔丙大   19630529   남   51               시·도의회의원선거
# 3095         민병두          閔丙梪   19580610   남   57                  국회의원선거
# 3096         민병록          閔丙祿   19531003   남   62                  국회의원선거
# 3097         민병숙          閔丙淑   19540829   여   59              광역의원비례대표선거
# 3098         민병욱          閔丙煜   19780118   남   36             구·시·군의회의원선거
# 3099         민병조          閔炳祚   19560922   남   57              기초의원비례대표선거
#
#       ElectionDate                     Position L1_Division L2_Division  ...  \
# 3000      20140604        Party List Legislator       울산광역시         NaN  ...
# 3001      20160413                   Legislator       인천광역시         부평구  ...
# 3002      20140604                   Legislator         경기도         하남시  ...
# 3003      20140604                   Legislator       서울특별시         서초구  ...
# 3004      20160413                   Legislator        전라남도         목포시  ...
# 3005      20140604                   Legislator       서울특별시         성동구  ...
# 3006      20140604                   Legislator        경상남도         의령군  ...
# 3007      20140604                   Legislator         경기도         과천시  ...
# 3008      20140604                   Legislator       서울특별시         노원구  ...
# 3009      20140604                   Legislator         경기도        의정부시  ...
# 3010      20140604                   Legislator       광주광역시          북구  ...
# 3011      20140604                        Chief         강원도         인제군  ...
# 3012      20140604                   Legislator       울산광역시          북구  ...
# 3013      20140604                   Legislator        충청남도         보령시  ...
# 3014      20140604                        Chief       서울특별시        서대문구  ...
# 3015      20140604     Education Council Member     제주특별자치도        서귀포시  ...
# 3016      20140604        Party List Legislator       광주광역시          서구  ...
# 3017      20140604                   Legislator        전라남도         나주시  ...
# 3018      20140604                   Legislator        경상남도         통영시  ...
# 3019      20140604                   Legislator       부산광역시         연제구  ...
# 3020      20140604                   Legislator       대전광역시         대덕구  ...
# 3021      20140604                   Legislator        전라북도         김제시  ...
# 3022      20140604                   Legislator         경기도      안양시동안구  ...
# 3023      20140604                   Legislator        경상남도    창원시마산회원구  ...
# 3024      20140604                   Legislator       인천광역시          서구  ...
# 3025      20140604                   Legislator         경기도         가평군  ...
# 3026      20140604                   Legislator        전라남도         무안군  ...
# 3027      20140604                   Legislator        경상남도         진주시  ...
# 3028      20140604                   Legislator        전라남도         광양시  ...
# 3029      20140604                   Legislator       부산광역시          북구  ...
# 3030      20140604                   Legislator         경기도         오산시  ...
# 3031      20140604                   Legislator       부산광역시          북구  ...
# 3032      20140604                   Legislator        전라북도         임실군  ...
# 3033      20140604                   Legislator       부산광역시        부산진구  ...
# 3034      20140604                   Legislator       인천광역시          남구  ...
# 3035      20140604                   Legislator       서울특별시         양천구  ...
# 3036      20140604        Party List Legislator        충청남도         태안군  ...
# 3037      20160413                   Legislator         경기도      용인시기흥구  ...
# 3038      20140604                   Legislator       대전광역시          서구  ...
# 3039      20140604        Party List Legislator        경상남도      창원시의창구  ...
# 3040      20140604                   Legislator         경기도         하남시  ...
# 3041      20140604  Superintendent of Education       서울특별시         NaN  ...
# 3042      20140604                   Legislator       서울특별시         송파구  ...
# 3043      20140604                   Legislator       서울특별시         서초구  ...
# 3044      20140604                   Legislator        경상북도         고령군  ...
# 3045      20140604                   Legislator       부산광역시          서구  ...
# 3046      20140604                   Legislator       서울특별시         강남구  ...
# 3047      20170509                        Chief         NaN         NaN  ...
# 3048      20140604        Party List Legislator       부산광역시         NaN  ...
# 3049      20140604                   Legislator         경기도         시흥시  ...
# 3050      20140604                   Legislator        경상남도         밀양시  ...
# 3051      20140604        Party List Legislator       부산광역시         기장군  ...
# 3052      20140604                   Legislator       서울특별시         마포구  ...
# 3053      20140604                        Chief        충청남도         금산군  ...
# 3054      20160413                   Legislator       광주광역시         광산구  ...
# 3055      20140604                   Legislator         강원도         원주시  ...
# 3056      20140604                   Legislator        전라남도         광양시  ...
# 3057      20140604                   Legislator       대전광역시          중구  ...
# 3058      20140604                   Legislator       인천광역시         남동구  ...
# 3059      20140604                   Legislator       서울특별시         광진구  ...
# 3060      20140604                        Chief        경상남도         남해군  ...
# 3061      20160413        Party List Legislator          전국          전국  ...
# 3062      20140604                   Legislator       부산광역시         기장군  ...
# 3063      20140604                   Legislator        전라북도         부안군  ...
# 3064      20140604                   Legislator        전라남도         강진군  ...
# 3065      20160413                   Legislator       광주광역시          동구  ...
# 3066      20140604                        Chief       서울특별시         동작구  ...
# 3067      20140604                   Legislator         경기도         광주시  ...
# 3068      20140604                   Legislator       광주광역시         광산구  ...
# 3069      20140604                   Legislator        충청남도      천안시동남구  ...
# 3070      20160413                   Legislator         경기도         하남시  ...
# 3071      20140604                   Legislator        전라남도         화순군  ...
# 3072      20160413                   Legislator         경기도         광명시  ...
# 3073      20140604                   Legislator       인천광역시          서구  ...
# 3074      20140604                   Legislator       서울특별시        서대문구  ...
# 3075      20140604                   Legislator         경기도      용인시기흥구  ...
# 3076      20140604                   Legislator       광주광역시          동구  ...
# 3077      20140604                   Legislator        전라북도         임실군  ...
# 3078      20160413                   Legislator     세종특별자치시     세종특별자치시  ...
# 3079      20160413                   Legislator         경기도        의정부시  ...
# 3080      20140604                   Legislator       부산광역시          남구  ...
# 3081      20140604                   Legislator        경상북도         상주시  ...
# 3082      20160413                   Legislator        전라북도         완주군  ...
# 3083      20140604                   Legislator         경기도      고양시덕양구  ...
# 3084      20140604                   Legislator        충청북도         옥천군  ...
# 3085      20160413                   Legislator       인천광역시         연수구  ...
# 3086      20160413        Party List Legislator          전국          전국  ...
# 3087      20140604                   Legislator         경기도         구리시  ...
# 3088      20140604                   Legislator       인천광역시          남구  ...
# 3089      20140604                   Legislator       대전광역시          중구  ...
# 3090      20140604                   Legislator        전라남도         해남군  ...
# 3091      20140604                   Legislator        전라북도         완주군  ...
# 3092      20140604                   Legislator       인천광역시          중구  ...
# 3093      20140604                   Legislator         경기도      부천시원미구  ...
# 3094      20140604                   Legislator        전라남도         여수시  ...
# 3095      20160413                   Legislator       서울특별시        동대문구  ...
# 3096      20160413                   Legislator       서울특별시         중랑구  ...
# 3097      20140604        Party List Legislator         경기도         NaN  ...
# 3098      20140604                   Legislator        경상북도       포항시북구  ...
# 3099      20140604        Party List Legislator        경상북도         상주시  ...
#
#       CandidateStatus WonElection   VoteCount VotePercent IncumbentStatus  \
# 3000               등록           1         NaN         NaN             NaN
# 3001               등록           0         NaN         NaN             NaN
# 3002               등록           0         NaN         NaN             NaN
# 3003               등록           1      8385.0       34.17             NaN
# 3004               등록           0         NaN         NaN             NaN
# 3005               등록           1      6902.0       19.15             NaN
# 3006               등록           1      1293.0       33.75             NaN
# 3007               등록           1      4713.0       26.36             NaN
# 3008               등록           1     22270.0       53.83             NaN
# 3009               등록           0         NaN         NaN             NaN
# 3010               등록           1     20707.0       67.72             NaN
# 3011               등록           0         NaN         NaN             NaN
# 3012               등록           1     15421.0       53.21             NaN
# 3013               등록           0         NaN         NaN             NaN
# 3014               등록           1     86613.0       55.00             NaN
# 3015               등록           0         NaN         NaN             NaN
# 3016               등록           0         NaN         NaN             NaN
# 3017               등록           0         NaN         NaN             NaN
# 3018               등록           1      3055.0       46.38             NaN
# 3019               등록           0         NaN         NaN             NaN
# 3020               등록           1      6869.0       25.84             NaN
# 3021               등록           0         NaN         NaN             NaN
# 3022               등록           1     14348.0       35.37             NaN
# 3023               등록           0         NaN         NaN             NaN
# 3024               등록           1      9082.0       30.59             NaN
# 3025               등록           0         NaN         NaN             NaN
# 3026               등록           0         NaN         NaN             NaN
# 3027               등록           0         NaN         NaN             NaN
# 3028               등록           1      5368.0       20.43             NaN
# 3029               등록           1      5280.0       25.94             NaN
# 3030               등록           1     11349.0       30.72             NaN
# 3031               등록           1      4333.0       22.82             NaN
# 3032               등록           1      1997.0       24.95             NaN
# 3033               등록           1      9232.0       31.36             NaN
# 3034               등록           1      5256.0       13.11             NaN
# 3035               등록           1     30621.0       46.30             NaN
# 3036               등록           0         NaN         NaN             NaN
# 3037               등록           0         NaN         NaN             NaN
# 3038               등록           0         NaN         NaN             NaN
# 3039               등록           0         NaN         NaN             NaN
# 3040               등록           1      8803.0       27.53             NaN
# 3041               등록           0         NaN         NaN             NaN
# 3042               등록           1     13656.0       40.48             NaN
# 3043               등록           0         NaN         NaN             NaN
# 3044               사퇴           0         NaN         NaN             NaN
# 3045               등록           0         NaN         NaN             NaN
# 3046               등록           1     10644.0       34.80             NaN
# 3047               등록           1  13423800.0       41.08             NaN
# 3048               등록           0         NaN         NaN             NaN
# 3049               등록           1     12266.0       27.93             NaN
# 3050               등록           0         NaN         NaN             NaN
# 3051               등록           1         NaN         NaN             NaN
# 3052               등록           1      3870.0       25.47             NaN
# 3053               등록           0         NaN         NaN             NaN
# 3054               등록           0         NaN         NaN             NaN
# 3055               등록           0         NaN         NaN             NaN
# 3056               등록           0         NaN         NaN             NaN
# 3057               등록           1     10052.0       39.76             NaN
# 3058               등록           1      7315.0       17.96             NaN
# 3059               등록           1     26487.0       57.33             NaN
# 3060               등록           0         NaN         NaN             NaN
# 3061               등록           1         NaN         NaN             NaN
# 3062               등록           0         NaN         NaN             NaN
# 3063               등록           1      1756.0       26.44             NaN
# 3064               등록           1      1446.0       14.59             NaN
# 3065               등록           0         NaN         NaN             NaN
# 3066               사퇴           0         NaN         NaN             NaN
# 3067               등록           0         NaN         NaN             NaN
# 3068               등록           1     21115.0       56.53             NaN
# 3069               등록           0         NaN         NaN             NaN
# 3070               등록           0         NaN         NaN             NaN
# 3071               등록           1     11629.0       44.58             NaN
# 3072               등록           0         NaN         NaN             NaN
# 3073               등록           0         NaN         NaN             NaN
# 3074               등록           1     19456.0       52.06             NaN
# 3075               등록           0         NaN         NaN             NaN
# 3076               등록           0         NaN         NaN             NaN
# 3077               등록           1      1467.0       27.11             NaN
# 3078               등록           0         NaN         NaN             NaN
# 3079               등록           1     38739.0       42.84             NaN
# 3080               등록           0         NaN         NaN             NaN
# 3081               등록           0         NaN         NaN             NaN
# 3082               등록           0         NaN         NaN             NaN
# 3083               등록           1     23709.0       50.19             NaN
# 3084               등록           1      2493.0       30.55             NaN
# 3085               등록           1     32963.0       44.35             NaN
# 3086               등록           0         NaN         NaN             NaN
# 3087               등록           1      9563.0       23.50             NaN
# 3088               등록           0         NaN         NaN             NaN
# 3089               등록           0         NaN         NaN             NaN
# 3090               등록           0         NaN         NaN             NaN
# 3091               등록           0         NaN         NaN             NaN
# 3092               등록           0         NaN         NaN             NaN
# 3093               등록           1      6608.0       22.74             NaN
# 3094               등록           0         NaN         NaN             NaN
# 3095               등록           1     49942.0       58.16             NaN
# 3096               등록           0         NaN         NaN             NaN
# 3097               등록           1         NaN         NaN             NaN
# 3098               등록           0         NaN         NaN             NaN
# 3099               등록           1         NaN         NaN             NaN
#
#                 Occupation                               Education  \
# 3000                  사회복지                   동국대 사회과학대학원 졸업(사회복지학)
# 3001                  국회의원                       서울대학교 법과대학 법학과 졸업
# 3002                   회사원         전신서해공업전문대학(현 호원대학교) 토목과 졸업 (2년)
# 3003                   연구원              한양대학교 도시대학원 석사과정 졸업(도시학석사)
# 3004                   정당인  나고야대학대학원 법학박사과정수료(2000.4.1~2006.3.31.)
# 3005                   정당인                       한국방송통신대학교 교육학과 졸업
# 3006               의령군의회의원                       한국방송통신대학교 행정학과 졸업
# 3007                   정당인                 동국대학교 문화예술대학원 졸업(문학 석사)
# 3008            서울특별시의회 의원               광운대학교 상담복지정책대학원 사회복지학과 재학
# 3009                   정당인                   한국방송통신대학교 경영학과 1학년 제적
# 3010             광주광역시의회의원                     전남대학교 행정대학원 행정학과 졸업
# 3011                   정치인                강원대학교 대학원 정치외교학과 박사과정 수료
# 3012            주)현대자동차 근무                       영산대학교 법경대 행정학과 졸업
# 3013                   정당인                    한남대학교 경상대학 지역개발학과 졸업
# 3070                      (전)청와대 정무1 비서관
# 3071               (전)민주평화통일자문회의 화순군협의회장
# 3072                        (전)광명시의회 부의장
# 3073         (전)제6대 인천광역시서구의회의원(기획총무위원장)
# 3074          (현) 새정치민주연합 서울시당 교육연수 부위원장
# 3075                         (전) 경기도교육의원
# 3076                  (현)동구마을기업 빛고을TV 이사
# 3077                    (현)임실군 재향군인회 부회장
# 3078                    (전)서울중앙지방법원 부장판사
# 3079                     (전)참여정부 대통령비서실장
# 3080                     (전)남구 청년 연합회 회장
# 3081                       (전)상주상록회 사무국장
# 3082                       (전)대구한의대학교 교수
# 3083                  (전)최성 국회의원 보좌관(4급)
# 3084                     (전)제5대 옥천군의회부의장
# 3085                         (전) 청와대 대변인
# 3086                 (전) 경기 경제단체연합회 사무총장
# 3087                         (현) 구리시의회의원
# 3088              (현) 인천환경운동연합 남구지회 운영위원
# 3089                (전)새누리당 박근혜 대통령후보 특보
# 3090                          (전)중부건설 대표
# 3091             (전) 민주노총 전북 도립국악원 노조위원장
# 3092                (전) (사)인천항발전협의회 사무국장
# 3093                        (현)부일장학회 이사장
# 3094                (전)여수MBC(주) 편성제작팀 부장
# 3095                      (전)문화일보 워싱턴특파원
# 3096                (전)국민회의 서울특별시당 공동위원장
# 3097                 (전)육군 간호병과장(예비역 대령)
# 3098           (전)경산시 학교급식조례개정운동본부 집행위원장
# 3099                     (전)김종태국회의원실 비서관
#
#                                        Career2 URL_NamuWiki
# 3000             (전)제18대 대선 새누리당 울산선대위 선거대책위원장          NaN
# 3001                         (현)국민의당 인천광역시당위원장          NaN
# 3002                             (현) 하남시문화원 이사          NaN
# 3003                         (현)한국산지보전협회 선임연구원          NaN
# 3004                             (현)정의당 정책연구위원          NaN
# 3005            (현) 대한적십자사 서울특별시지사 성동구후원회 사무국장          NaN
# 3006                (현)제6대 의령군의회 상·하반기 산업건설위원장          NaN
# 3007                     (현)한국문인협회 과천지부 상임 부회장          NaN
# 3008  (현)2018 평창동계올림픽지원 및 서울시스포츠 활성화를 위한 특별위원장          NaN
# 3009                    (현) 의정부시 청소년지도협의회 사무국장          NaN
# 3010                    (전) 6대 광주광역시의회 환경복지위원장          NaN
# 3011                              (전)내무부장관 비서관          NaN
# 3012                   (현) 울산광역시 북구 아파트연합회 부회장          NaN
# 3013                          (현)보령시민참여연대 운영위원          NaN
# 3014                                 (현)서대문구청장          NaN
# 3015                         (현)제주특별자치도의회교육의원장          NaN
# 3016                     (현)민주평화통일자문회의2030홍보부장          NaN
# 3017                 (현)새정치민주연합 나주화순지역위원회 부위원장          NaN
# 3018                         (현)통영시 수산조정위원회 위원          NaN
# 3019                              (전)부산연제구청 근무          NaN
# 3020                           (현)신탄진 축구연합회 회장          NaN
# 3021                            (현)공덕면지역발전협의회장          NaN
# 3022                       (전)안양시의회 5대 후반기 부의장          NaN
# 3023                                  (현)창원시의원          NaN
# 3024                      (전)인천광역시 서구 민주산악회 회장          NaN
# 3025                     (현)청평 얼음꽃 송어축제위원회 위원장          NaN
# 3026                          (현)중국천진시 고급 경제고문          NaN
# 3027                        (현)진주시읍면동풍물단협의회 회장          NaN
# 3028                   (전) 민주당 광양.구례지역위원회 사무국장          NaN
# 3029                  (전) 2012문재인 대선북구선대위 부본부장          NaN
# 3030                           (전)오산환경운동연합운영위원          NaN
# 3031                         (전) 민주당부산시당 청년위원장          NaN
# 3032                            (현)임실군의회 6대 의원          NaN
# 3033                         (전) 금정전자공업고등학교 교사          NaN
# 3034                            (현) 남구의회 6대 의원          NaN
# 3035                       (전)민주당 지방자치위원회 부위원장          NaN
# 3036                                       NaN          NaN
# 3037                               (현)용인청년회 회장          NaN
# 3038                                       NaN          NaN
# 3039                 (현) 민주노총경남도본부 일반노동조합 부위원장          NaN
# 3040              (현)민주평화통일자문회의 하남시협의회 여성분과위원장          NaN
# 3041                          (전)서울대학교 교육학과 교수          NaN
# 3042                                (전)서울시 공무원          NaN
# 3043                   (현)세금바로쓰기 서초지부 여성정책 위원장          NaN
# 3044             (전)고령신문사, 고령성주신문사 편집국장 및 상임이사          NaN
# 3045                              (전)지성기업 대표이사          NaN
# 3046                           (현)강남구의회(6대) 의원          NaN
# 3047                              (전)제19대 국회의원          NaN
# 3048                                       NaN          NaN
# 3049                             (현) 제6대 시흥시의원          NaN
# 3050                                       NaN          NaN
# 3051                           (전)해운대교육지원청 교육장          NaN
# 3052                                (현)체리투어 감사          NaN
# 3053                                (현)웅지농산 대표          NaN
# 3054                        (현) 정의당 광산구위원회 위원장          NaN
# 3055                 (전)문재인 제18대 대통령후보 청년특별보좌관          NaN
# 3056                          (현) 소호무역협동조합 이사장          NaN
# 3057                          (현)제6대 대전 중구의회의원          NaN
# 3058                          (현)인천호남향우회본회 부회장          NaN
# 3059                                  (현)사회복지사          NaN
# 3060                           (현)남해미래정책연구소 소장          NaN
# 3061                            (현) 전국택시노련 위원장          NaN
# 3062                             (현)노인사랑모임회 회장          NaN
# 3063                           (현)부안군사회복지협의회회장          NaN
# 3064                   (현)전국 사회적경제기초의원협의회 공동대표          NaN
# 3065                      (현)민주평통 광주동구협의회 자문위원          NaN
# 3066                           (전)마포, 동대문 부구청장          NaN
# 3067                         (현)광주시 농민단체협의회 회장          NaN
# 3068                   (전) 한라그룹 한라엔컴 담양사업소장 부장          NaN
# 3069                           (현)천안시 축구연합회 회장          NaN
# 3070                          (전)제17대,18대 국회의원          NaN
# 3071                        (전)제5, 6대 화순군의회 의원          NaN
# 3072                          (현)정의당 광명갑 지역위원장          NaN
# 3073                         (전)검암,청라주민자치위원회고문          NaN
# 3074                   (전) 홍은초등학교 제9기 학부모운영위원장          NaN
# 3075                    (현) 용인 고교평준화 자문위원회 위원장          NaN
# 3076                        (현)통합진보당 동구지역위 위원장          NaN
# 3077                             (현)임실군의회 6대의원          NaN
# 3078                        (전)국회 윤리심사위원회 자문위원          NaN
# 3079                              (현)제19대 국회의원          NaN
# 3080                        (전)문현 여자 중학교 운영위원장          NaN
# 3081               (현)법교육 · 학교폭력예방교육 및 분쟁조정센터장          NaN
# 3082                           (전)전국대학레슬링연맹 회장          NaN
# 3083                        (현)고양시 일자리창출위원회 위원          NaN
# 3084                            (현)제6대 옥천군의회의원          NaN
# 3085                          (전) KBS 9시 뉴스 앵커          NaN
# 3086                        (현) 인구보건복지협회 경기지회장          NaN
# 3087                            (전) 아이다 작은도서관장          NaN
# 3088                       (현) 한국나누리복지협회 자문위원장          NaN
# 3089                      (전)남대전 청년회의소(J.C) 회장          NaN
# 3090                               (전)호남매일신문기자          NaN
# 3091                     (현) 완주자율관리영어조합법인 대표이사          NaN
# 3092                            (전) 중구재향군인회 이사          NaN
# 3093                   (전)상2동 주민자치위원장(7년9개월)역임          NaN
# 3094                (현)여수세계박람회 사후활용 추진위원회 홍보팀장          NaN
# 3095                             (현)민주정책연구원 원장          NaN
# 3096                      (현)국민의당 서울특별시당 공동위원장          NaN
# 3097                           (현)재향여성군인협의회 회장          NaN
# 3098                       (현) 포항119희망민생상담소 소장          NaN
# 3099                   (현)새누리당경북도당홍보위원회 수석부위원장          NaN
#
# [100 rows x 24 columns]

# %%
# percent duplicates

1 - (sktest["Name_Native"].drop_duplicates().shape[0] / sktest.shape[0])
# Out:
# 0.12550200803212852

# %% [markdown]
# # scrape namuwiki with selenium

# %%
url_stem = "https://namu.wiki"

p_error_name = "data-v-1ac09f2e"
p_error_text = "해당 문서를 찾을 수 없습니다."

# %%
# instantiate selenium webdriver
service = Service(executable_path=ChromeDriverManager().install())

# scrape namuwiki using selenium
for index,p in sktest.iterrows():
    
    if(pd.isnull(p.URL_NamuWiki)):
    
        # construct url - encode non-ASCII search terms as ASCII
        url= url_stem+"/w/"+urllib.parse.quote(p.Name_Native.encode("utf-8"))

        # reset content & has_content_flag
        has_content_flag = True
        content=""

        try:

            # request url using selenium webdriver
            driver = webdriver.Chrome(service=service)
            driver.get(url)

            # check if page has content
            elements = driver.find_elements(By.TAG_NAME, 'p')

            for e in elements:
                if(e.text==p_error_text):
                    has_content_flag = False

            if(has_content_flag):
                content = driver.page_source

            # close webdriver
            driver.quit()

            # save content
            if(has_content_flag):

                # save output as an html file
                fout = open(fileout_path+"seleniumtest_"+str(index)+"_"+p.Name_Native+".html","w",encoding="utf-8")
                fout.write(content)
                fout.close()

                # update HasNamuWiki content field in dataframe
                #sktest.loc[sktest.Name_Native == p.Name_Native,'URL_NamuWiki']=url

                # save result to log file
                log_output = ",".join([str(index),p.Name_Native,url,"\n"])
                fout = open(fileout_path+logfile_name,"a",encoding="utf-8")
                fout.write(log_output)
                fout.close()

                print(index,p.Name_Native,url,"Number of <p> elements:",len(elements),"Has Content")

            else:

                # update HasNamuWiki content field in dataframe
                # sktest.loc[sktest.Name_Native == p.Name_Native,'URL_NamuWiki']=False

                # save result to log file
                log_output = ",".join([str(index),p.Name_Native,"False","\n"])
                fout = open(fileout_path+logfile_name,"a",encoding="utf-8")
                fout.write(log_output)
                fout.close()

                print(index,p.Name_Native,url,"Number of <p> elements:",len(elements),"Empty")
            
        except KeyboardInterrupt:
        
            print("Keyboard Interrupt")
            
            break

        except Exception as e:

            print(index,p.Name_Native,url,"Number of <p> elements:",len(elements),"Error")
            print(e)
# Out:
# 2506 김하용 https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%9A%A9 Number of <p> elements: 4 Has Content
# 2507 김하중 https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%A4%91 Number of <p> elements: 4 Has Content
# 2508 김학관 https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B4%80 Number of <p> elements: 4 Has Content
# 2509 김학구 https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B5%AC Number of <p> elements: 5 Empty
# 2510 김학규 https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B7%9C Number of <p> elements: 4 Has Content
# 2511 김학기 https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B8%B0 Number of <p> elements: 4 Has Content
# 2512 김학두 https://namu.wiki/w/%EA%B9%80%ED%95%99%EB%91%90 Number of <p> elements: 5 Empty
# 2513 김학만 https://namu.wiki/w/%EA%B9%80%ED%95%99%EB%A7%8C Number of <p> elements: 5 Empty
# 2514 김학성 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%84%B1 Number of <p> elements: 4 Has Content
# 2515 김학수 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%88%98 Number of <p> elements: 4 Has Content
# 2516 김학영 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%98%81 Number of <p> elements: 5 Empty
# 2517 김학용 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9A%A9 Number of <p> elements: 4 Has Content
# 2518 김학원 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9B%90 Number of <p> elements: 4 Has Content
# 2519 김학유 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9C%A0 Number of <p> elements: 5 Empty
# 2520 김학일 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9D%BC Number of <p> elements: 5 Empty
# 2521 김학천 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%9C Number of <p> elements: 5 Empty
# 2522 김학철 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0 Number of <p> elements: 4 Has Content
# 2523 김학철 https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0 Number of <p> elements: 4 Has Content
# 2524 김학희 https://namu.wiki/w/%EA%B9%80%ED%95%99%ED%9D%AC Number of <p> elements: 5 Empty
# 2525 김한구 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B5%AC Number of <p> elements: 5 Empty
# 2526 김한규 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B7%9C Number of <p> elements: 4 Has Content
# 2527 김한기 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B8%B0 Number of <p> elements: 4 Has Content
# 2528 김한수 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98 Number of <p> elements: 4 Has Content
# 2529 김한수 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98 Number of <p> elements: 4 Has Content
# 2530 김한울 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%9A%B8 Number of <p> elements: 4 Has Content
# 2531 김한정 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A0%95 Number of <p> elements: 4 Has Content
# 2532 김한중 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A4%91 Number of <p> elements: 4 Has Content
# 2533 김한창 https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%B0%BD Number of <p> elements: 5 Empty
# 2534 김한태 https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C Number of <p> elements: 4 Has Content
# 2535 김한태 https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C Number of <p> elements: 4 Has Content
# 2536 김한표 https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%91%9C Number of <p> elements: 4 Has Content
# 2537 김한호 https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%98%B8 Number of <p> elements: 5 Empty
# 2538 김항곤 https://namu.wiki/w/%EA%B9%80%ED%95%AD%EA%B3%A4 Number of <p> elements: 4 Has Content
# 2539 김항대 https://namu.wiki/w/%EA%B9%80%ED%95%AD%EB%8C%80 Number of <p> elements: 5 Empty
# Keyboard Interrupt

# %%
sktest[sktest.Name_Native=="강민국"]
# Out:
#    Name_Native Name_Chinese  Birthdate Sex  Age ElectionCategory_Native  \
# 60         강민국          姜旻局   19710303   남   43               시·도의회의원선거
#
#     ElectionDate    Position L1_Division L2_Division  ...  CandidateStatus  \
# 60      20140604  Legislator        경상남도         진주시  ...               등록
#
#    WonElection VoteCount VotePercent IncumbentStatus  Occupation  \
# 60           1   28248.0       75.31             NaN         정당인
#
#              Education           Career1        Career2  \
# 60  경남대학교 대학원 졸업(법학박사)  (전)경상남도 도지사 비서실장  (전)경상남도 정무보좌역
#
#                                        URL_NamuWiki
# 60  https://namu.wiki/w/%EA%B0%95%EB%AF%BC%EA%B5%AD
#
# [1 rows x 24 columns]

# %%
# things to check

# 0. drop duplicates. some duplicate pages are different (at least size differs). why?  

# 0.1 drop duplicates (by=[Name_Native, Name_Chinese, Birthdate]) in TW dataset, before scraping

# 1. saved links are valid (no false positives); False links actually don't exist (no false negatives)

# 2. disambiguation? what about names that link to more than one person?
#
#       - disambiguation links are usually included in the page
#
#       - redirect from the page of a more popular person
#               https://namu.wiki/w/%EA%B0%95%EB%AF%BC%EA%B5%AD - 강민국
#               정치인에 대한 내용은 강민국(정치인) 문서를 참고하십시오.
#               https://namu.wiki/w/%EA%B0%95%EB%AF%BC%EA%B5%AD(%EC%A0%95%EC%B9%98%EC%9D%B8) - 강민국(정치인)
#
#       - redirects from a page listing links to multiple people having the same name
#               https://namu.wiki/w/%EA%B9%80%EC%9A%A9%EC%A7%84

# %% [markdown]
# # update sktest with selenium log from latest run

# %%
log_columns = ["index","Name_Native","url","dropme"]
log = pd.read_csv(fileout_path+logfile_name,header=None,encoding="utf-8",names=log_columns)
log.drop(columns=["dropme"],inplace=True)
log
# Out:
#     index Name_Native                                              url
# 0    2506         김하용  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%9A%A9
# 1    2507         김하중  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%A4%91
# 2    2508         김학관  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B4%80
# 3    2509         김학구                                            False
# 4    2510         김학규  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B7%9C
# 5    2511         김학기  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B8%B0
# 6    2512         김학두                                            False
# 7    2513         김학만                                            False
# 8    2514         김학성  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%84%B1
# 9    2515         김학수  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%88%98
# 10   2516         김학영                                            False
# 11   2517         김학용  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9A%A9
# 12   2518         김학원  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9B%90
# 13   2519         김학유                                            False
# 14   2520         김학일                                            False
# 15   2521         김학천                                            False
# 16   2522         김학철  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 17   2523         김학철  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 18   2524         김학희                                            False
# 19   2525         김한구                                            False
# 20   2526         김한규  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B7%9C
# 21   2527         김한기  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B8%B0
# 22   2528         김한수  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 23   2529         김한수  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 24   2530         김한울  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%9A%B8
# 25   2531         김한정  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A0%95
# 26   2532         김한중  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A4%91
# 27   2533         김한창                                            False
# 28   2534         김한태  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 29   2535         김한태  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 30   2536         김한표  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%91%9C
# 31   2537         김한호                                            False
# 32   2538         김항곤  https://namu.wiki/w/%EA%B9%80%ED%95%AD%EA%B3%A4
# 33   2539         김항대                                            False

# %%
sktest.shape
# Out:
# (9960, 24)

# %%
sktest_updated = sktest.merge(log,how="left",on="Name_Native")
sktest_updated.shape
# Out:
# (9966, 26)

# %%
# update URL_NamuWiki with log results
sktest_updated.loc[sktest_updated.URL_NamuWiki.isnull() & sktest_updated.url.notnull(),"URL_NamuWiki"] = sktest_updated.loc[sktest_updated.URL_NamuWiki.isnull() & sktest_updated.url.notnull(),"url"]

# confirm that changes have been made
sktest_updated.loc[sktest_updated.url.notnull(),["URL_NamuWiki","url"]]
# Out:
#                                          URL_NamuWiki  \
# 2506  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%9A%A9
# 2507  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%A4%91
# 2508  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B4%80
# 2509                                            False
# 2510  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B7%9C
# 2511  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B8%B0
# 2512                                            False
# 2513                                            False
# 2514  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%84%B1
# 2515  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%88%98
# 2516                                            False
# 2517  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9A%A9
# 2518  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9B%90
# 2519                                            False
# 2520                                            False
# 2521                                            False
# 2522  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2523  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2524  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2525  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2526                                            False
# 2527                                            False
# 2528  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B7%9C
# 2529  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B8%B0
# 2530  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2531  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2532  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2533  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2534  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%9A%B8
# 2535  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A0%95
# 2536  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A4%91
# 2537                                            False
# 2538  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2539  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2540  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2541  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2542  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%91%9C
# 2543                                            False
# 2544  https://namu.wiki/w/%EA%B9%80%ED%95%AD%EA%B3%A4
# 2545                                            False
#
#                                                   url
# 2506  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%9A%A9
# 2507  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%A4%91
# 2508  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B4%80
# 2509                                            False
# 2510  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B7%9C
# 2511  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B8%B0
# 2512                                            False
# 2513                                            False
# 2514  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%84%B1
# 2515  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%88%98
# 2516                                            False
# 2517  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9A%A9
# 2518  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9B%90
# 2519                                            False
# 2520                                            False
# 2521                                            False
# 2522  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2523  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2524  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2525  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2526                                            False
# 2527                                            False
# 2528  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B7%9C
# 2529  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B8%B0
# 2530  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2531  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2532  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2533  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2534  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%9A%B8
# 2535  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A0%95
# 2536  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A4%91
# 2537                                            False
# 2538  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2539  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2540  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2541  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2542  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%91%9C
# 2543                                            False
# 2544  https://namu.wiki/w/%EA%B9%80%ED%95%AD%EA%B3%A4
# 2545                                            False

# %%
# change "False" strings to boolean False
sktest_updated.loc[sktest_updated.URL_NamuWiki=="False","URL_NamuWiki"]=False

# %%
sktest_updated[sktest_updated["index"].notnull()]
# Out:
#      Name_Native Name_Chinese  Birthdate Sex  Age ElectionCategory_Native  \
# 2506         김하용          金夏龍   19501105   남   63             구·시·군의회의원선거
# 2507         김하중          金夏中   19600620   남   55                  국회의원선거
# 2508         김학관          金學灌   19550915   남   58              구·시·군의 장선거
# 2509         김학구          金學球   19640312   남   50             구·시·군의회의원선거
# 2510         김학규          金學奎   19471214   남   66              구·시·군의 장선거
# 2511         김학기          金學起   19600324   남   54              구·시·군의 장선거
# 2512         김학두          金學杜   19640520   남   50               시·도의회의원선거
# 2513         김학만          金學萬   19571204   남   56               시·도의회의원선거
# 2514         김학성          金學性   19571224   남   56             구·시·군의회의원선거
# 2515         김학수          金學洙   19660607   남   47             구·시·군의회의원선거
# 2516         김학영          金學英   19520912   남   61              구·시·군의 장선거
# 2517         김학용          金學容   19611210   남   54                  국회의원선거
# 2525      20140604  Legislator         경기도         시흥시  ...        NaN
# 2526      20140604  Legislator        경상북도         칠곡군  ...     3155.0
# 2527      20140604  Legislator         강원도         삼척시  ...        NaN
# 2528      20140604  Legislator        경상북도         안동시  ...     2898.0
# 2529      20140604  Legislator        전라북도         임실군  ...        NaN
# 2530      20140604  Legislator         강원도         동해시  ...        NaN
# 2531      20140604  Legislator         강원도         동해시  ...        NaN
# 2532      20140604  Legislator        경상남도         거창군  ...        NaN
# 2533      20140604  Legislator        경상남도         거창군  ...        NaN
# 2534      20160413  Legislator       서울특별시         종로구  ...        NaN
# 2535      20160413  Legislator         경기도        남양주시  ...    36789.0
# 2536      20140604  Legislator        충청남도         서산시  ...        NaN
# 2537      20160413  Legislator        전라남도         목포시  ...        NaN
# 2538      20140604  Legislator        충청남도         보령시  ...     2687.0
# 2539      20140604  Legislator        충청남도         보령시  ...     2687.0
# 2540      20140604  Legislator         경기도      부천시원미구  ...    13704.0
# 2541      20140604  Legislator         경기도      부천시원미구  ...    13704.0
# 2542      20160413  Legislator        경상남도         거제시  ...    44908.0
# 2543      20140604  Legislator        경상남도         김해시  ...        NaN
# 2544      20140604       Chief        경상북도         성주군  ...    15995.0
# 2545      20140604  Legislator        경상북도         경주시  ...     3991.0
#
#      VotePercent IncumbentStatus        Occupation  \
# 2506       25.28             NaN               수산업
# 2507         NaN             NaN      전남대학교 로스쿨 교수
# 2508         NaN             NaN               정치인
# 2509         NaN             NaN       건설기계 굴삭기 운전
# 2510         NaN             NaN     선출직 공무원(용인시장)
# 2511         NaN             NaN               정당인
# 2512         NaN             NaN               정당인
# 2513         NaN             NaN          자산학원 이사장
# 2514         NaN             NaN                농업
# 2515       29.00             NaN             원주시의원
# 2516         NaN             NaN               정치인
# 2517       50.22             NaN              국회의원
# 2518       43.90             NaN          공무원(정무직)
# 2519         NaN             NaN                 무
# 2520         NaN             NaN      외교국방연구소 연구위원
# 2521         NaN             NaN                농업
# 2522       54.42             NaN               정당인
# 2523       54.42             NaN               정당인
# 2524         NaN             NaN      자영업(비엘.텍 대표)
# 2525         NaN             NaN      자영업(비엘.텍 대표)
# 2526       19.36             NaN               자영업
# 2527         NaN             NaN               자영업
# 2528       34.83             NaN                농업
# 2529         NaN             NaN               정치인
# 2530         NaN             NaN               정당인
# 2531         NaN             NaN               정당인
# 2532         NaN             NaN               자영업
# 2533         NaN             NaN               자영업
# 2534         NaN             NaN        종로구 지역 활동가
# 2535       38.63             NaN  연세대학교 원주캠퍼스 객원교수
# 2536         NaN             NaN               회사원
# 2537         NaN             NaN        동국대학교 객원교수
# 2538       23.65             NaN               운수업
# 2539       23.65             NaN               운수업
# 2540       35.31             NaN               정당인
# 2541       35.31             NaN               정당인
# 2542       44.19             NaN              국회의원
# 2543         NaN             NaN               정당인
# 2544       65.32             NaN               공무원
# 2545       19.74             NaN                무직
#
#                                             Education  \
# 2506                   부경대학교 대학원 수해양인적자원개발학과 석사과정 휴학중
# 2507                                   고려대학교 졸업(법학박사)
# 2508                        전주대학교 경영대학원 석사학위과정 1학기 휴학
https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%9A%B8  2530.0
# 2535  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A0%95  2531.0
# 2536  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A4%91  2532.0
# 2537                                            False  2533.0
# 2538  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C  2534.0
# 2539  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C  2535.0
# 2540  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C  2534.0
# 2541  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C  2535.0
# 2542  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%91%9C  2536.0
# 2543                                            False  2537.0
# 2544  https://namu.wiki/w/%EA%B9%80%ED%95%AD%EA%B3%A4  2538.0
# 2545                                            False  2539.0
#
#                                                   url
# 2506  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%9A%A9
# 2507  https://namu.wiki/w/%EA%B9%80%ED%95%98%EC%A4%91
# 2508  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B4%80
# 2509                                            False
# 2510  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B7%9C
# 2511  https://namu.wiki/w/%EA%B9%80%ED%95%99%EA%B8%B0
# 2512                                            False
# 2513                                            False
# 2514  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%84%B1
# 2515  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%88%98
# 2516                                            False
# 2517  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9A%A9
# 2518  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%9B%90
# 2519                                            False
# 2520                                            False
# 2521                                            False
# 2522  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2523  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2524  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2525  https://namu.wiki/w/%EA%B9%80%ED%95%99%EC%B2%A0
# 2526                                            False
# 2527                                            False
# 2528  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B7%9C
# 2529  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EA%B8%B0
# 2530  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2531  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2532  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2533  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%88%98
# 2534  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%9A%B8
# 2535  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A0%95
# 2536  https://namu.wiki/w/%EA%B9%80%ED%95%9C%EC%A4%91
# 2537                                            False
# 2538  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2539  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2540  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2541  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%83%9C
# 2542  https://namu.wiki/w/%EA%B9%80%ED%95%9C%ED%91%9C
# 2543                                            False
# 2544  https://namu.wiki/w/%EA%B9%80%ED%95%AD%EA%B3%A4
# 2545                                            False
#
# [40 rows x 26 columns]

# %%
# drop log column (url)
sktest_updated.drop(columns=["index","url"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-cff877345cc2> in <module>
#       1 # drop log column (url)
# ----> 2 sktest_updated.drop(columns=["index","url"],inplace=True)
#
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['index' 'url'] not found in axis"

# %%
# drop duplicate rows
sktest_updated.drop_duplicates().shape
# Out:
# (9960, 24)

# %%
# drop duplicate politicians
sktest_updated.sort_values(["Name_Native","Name_Chinese","Birthdate","ElectionDate"],inplace=True)
sktest_updated.drop_duplicates(["Name_Native","Name_Chinese","Birthdate"],keep="last",inplace=True)

# %%
sktest_updated.shape
# Out:
# (9960, 24)

# %%
# refresh and save updated sktest
sktest = sktest_updated
sktest.to_excel(filein_path+"sk_testset.xlsx",index=False)

# %%
# delete log file
os.remove(fileout_path+logfile_name)

# %%
# DEPRECATED - assign URL_NamuWiki link based on files already scraped - I needed this before I created a log file

# import os
# filelist = os.listdir(fileout_path)
# test = sktest
# url_stem = "https://namu.wiki"
# test[100:200]
# scraped = [f.split("_")[2].split(".")[0].strip() for f in filelist]
# for s in scraped:
#     url = url_stem+"/w/"+urllib.parse.quote(s.encode("utf-8"))
#     # print(url_stem+"/w/"+urllib.parse.quote(s.encode("utf-8")))
#     test.loc[test.Name_Native==s,"URL_NamuWiki"]=url
# test[100:200]
