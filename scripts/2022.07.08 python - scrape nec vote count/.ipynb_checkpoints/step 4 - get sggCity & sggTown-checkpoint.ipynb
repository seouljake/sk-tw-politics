# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %% [markdown]
# # Step 4 - get sggCity & sggTown
#
# #### sggCity for 구시군장, 기초의원 비례대표, 교육의원
# #### sggTown for 시도의원, 구시군의원, 시도 비례대표

# %% [markdown]
# ## check 구시군장 in Step 3.1

# %%
# import Step 3.1 - "get town" codes for 재보궐선거
filepath = "../../data/2.0 current through 2022 data/2022 NEC web scraping/step 3 - get town/dat_step3_1.xlsx"
dat_step3_1 = pd.read_excel(filepath,dtype=None)

# %%
dat_step3_1[["SubElectionCode","SubElectionName"]].drop_duplicates()
# Out:
#      SubElectionCode SubElectionName
# 0                  3         시·도지사선거
# 41                 4      구·시·군의 장선거
# 43                 5       시·도의회의원선거
# 51                 6     구·시·군의회의원선거
# 112                2          국회의원선거
# 140                4       구·시·군의장선거
# 314               11           교육감선거

# %%
dat_step3_1[dat_step3_1["SubElectionCode"]==4]
# Out:
#      ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 41                  0            재보궐선거      20210407   2021-04-07
# 42                  0            재보궐선거      20210407   2021-04-07
# 60                  0            재보궐선거      20200415   2020-04-15
# 61                  0            재보궐선거      20200415   2020-04-15
# 62                  0            재보궐선거      20200415   2020-04-15
# 63                  0            재보궐선거      20200415   2020-04-15
# 64                  0            재보궐선거      20200415   2020-04-15
# 65                  0            재보궐선거      20200415   2020-04-15
# 66                  0            재보궐선거      20200415   2020-04-15
# 67                  0            재보궐선거      20200415   2020-04-15
# 68                  0            재보궐선거      20200415   2020-04-15
# 140                 0            재보궐선거      20170412   2017-04-12
# 141                 0            재보궐선거      20170412   2017-04-12
# ...

# %%
dat_step3_1[dat_step3_1["TownCode"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ElectionTypeCode, ElectionTypeName, ElectionCode, ElectionName, SubElectionCode, SubElectionName, CityCode, CityName, TownCode, TownName]
# Index: []

# %% [markdown]
# ## check 구시군장 in Step 3.2

# %%
# import Step 3.2 - "get town" codes for 지선 1,2,3
filepath = "../../data/2.0 current through 2022 data/2022 NEC web scraping/step 3 - get town/dat_step3_2.xlsx"
dat_step3_2 = pd.read_excel(filepath,dtype=None)

# %%
dat_step3_2[["SubElectionCode","SubElectionName"]].drop_duplicates()
# Out:
#      SubElectionCode SubElectionName
# 0                  3         시·도지사선거
# 243                4       구·시·군의장선거
# 486                5       시·도의회의원선거
# 729                6     구·시·군의회의원선거
# 972                8      광역의원비례대표선거

# %%
dat_step3_2[dat_step3_2["SubElectionCode"]==4]
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 243                  4             지방선거      20020613          제3회
# 244                  4             지방선거      20020613          제3회
# 245                  4             지방선거      20020613          제3회
# 246                  4             지방선거      20020613          제3회
# 247                  4             지방선거      20020613          제3회
# ...                ...              ...           ...          ...
# 3288                 4             지방선거      19950627          제1회
# 3289                 4             지방선거      19950627          제1회
# 3290                 4             지방선거      19950627          제1회
# 3291                 4             지방선거      19950627          제1회
# 3292                 4             지방선거      19950627          제1회
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName
# 243                 4       구·시·군의장선거        11       서울      1101      종로구
# ...

# %%
dat_step3_2[dat_step3_2["TownName"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ElectionTypeCode, ElectionTypeName, ElectionCode, ElectionName, SubElectionCode, SubElectionName, CityCode, CityName, TownCode, TownName]
# Index: []

# %% [markdown]
# ## check 구시군장, 비례대표기초의원, 교육감의원 in Step 3.3

# %%
# import Step 3.3 - "get town" codes for everything else
filepath = "../../data/2.0 current through 2022 data/2022 NEC web scraping/step 3 - get town/dat_step3_3.xlsx"
dat_step3_3 = pd.read_excel(filepath,dtype=None)

# %%
dat_step3_3[["SubElectionCode","SubElectionName"]].drop_duplicates()
# Out:
#       SubElectionCode SubElectionName
# 0                   1           대통령선거
# 749                 2          국회의원선거
# 999                 7      비례대표국회의원선거
# 2751                3         시·도지사선거
# 3001                4      구·시·군의 장선거
# 3248                5       시·도의회의원선거
# 3498                6     구·시·군의회의원선거
# 3745                8      광역의원비례대표선거
# 3995                9      기초의원비례대표선거
# 4242               11           교육감선거
# 4492               10          교육의원선거
# 6493                4       구·시·군의장선거

# %%
dat_step3_3[dat_step3_3["SubElectionCode"]==4] # 구시군장
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 3001                 4             지방선거      20180613          제7회
# 3002                 4             지방선거      20180613          제7회
# 3003                 4             지방선거      20180613          제7회
# 3004                 4             지방선거      20180613          제7회
# 3005                 4             지방선거      20180613          제7회
# ...                ...              ...           ...          ...
# 8721                 4             지방선거      20060531          제4회
# 8722                 4             지방선거      20060531          제4회
# 8723                 4             지방선거      20060531          제4회
# 8724                 4             지방선거      20060531          제4회
# 8725                 4             지방선거      20060531          제4회
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName
# 3001                4      구·시·군의 장선거      1100    서울특별시      1101      종로구
# ...

# %%
dat_step3_3[dat_step3_3["SubElectionCode"]==9] # 기초의원 비례대표
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 3995                 4             지방선거      20180613          제7회
# 3996                 4             지방선거      20180613          제7회
# 3997                 4             지방선거      20180613          제7회
# 3998                 4             지방선거      20180613          제7회
# 3999                 4             지방선거      20180613          제7회
# ...                ...              ...           ...          ...
# 9713                 4             지방선거      20060531          제4회
# 9714                 4             지방선거      20060531          제4회
# 9715                 4             지방선거      20060531          제4회
# 9716                 4             지방선거      20060531          제4회
# 9717                 4             지방선거      20060531          제4회
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName
# 3995                9      기초의원비례대표선거      1100    서울특별시      1101      종로구
# ...

# %%
dat_step3_3[dat_step3_3["SubElectionCode"]==10] # 교육의원선거
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 4492                 4             지방선거      20180613          제7회
# 4493                 4             지방선거      20180613          제7회
# 6242                 4             지방선거      20140604          제6회
# 6243                 4             지방선거      20140604          제6회
# 7981                 4             지방선거      20100602          제5회
# ...                ...              ...           ...          ...
# 8229                 4             지방선거      20100602          제5회
# 9718                 4             지방선거      20060531          제4회
# 9719                 4             지방선거      20060531          제4회
# 9720                 4             지방선거      20060531          제4회
# 9721                 4             지방선거      20060531          제4회
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName
# 4492               10          교육의원선거      4900  제주특별자치도      4901      제주시
# ...
