# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %% [markdown]
# # Step 0 - import election type and election code

# %%
filepath = "../../data/2.0 current through 2022 data/2022 NEC web scraping/step 0 - election type/dat_step0.xlsx"
dat_step0 = pd.read_excel(filepath,dtype=None)
dat_step0_columns = list(dat_election.columns)

# %%
dat_step0
# Out:
#     ElectionTypeCode ElectionTypeName  ElectionCode ElectionName
# 0                  1            대통령선거      20170509         제19대
# 1                  1            대통령선거      20121219         제18대
# 2                  1            대통령선거      20071219         제17대
# 3                  2           국회의원선거      20200415         제21대
# 4                  2           국회의원선거      20160413         제20대
# 5                  2           국회의원선거      20120411         제19대
# 6                  2           국회의원선거      20080409         제18대
# 7                  4             지방선거      20180613          제7회
# 8                  4             지방선거      20140604          제6회
# 9                  4             지방선거      20100602          제5회
# 10                 4             지방선거      20060531          제4회
# 11                 4             지방선거      20020613          제3회
# 12                 4             지방선거      19980604          제2회
# 13                 4             지방선거      19950627          제1회
# 14                 0            재보궐선거      20210407   2021-04-07
# 15                 0            재보궐선거      20200415   2020-04-15
# 16                 0            재보궐선거      20190403   2019-04-03
# 17                 0            재보궐선거      20180613   2018-06-13
# 18                 0            재보궐선거      20170509   2017-05-09
# 19                 0            재보궐선거      20170412   2017-04-12
# 20                 0            재보궐선거      20160413   2016-04-13
# 21                 0            재보궐선거      20151028   2015-10-28
# 22                 0            재보궐선거      20150429   2015-04-29
# 23                 0            재보궐선거      20141029   2014-10-29
# 24                 0            재보궐선거      20140730   2014-07-30
# 25                 0            재보궐선거      20131030   2013-10-30
# 26                 0            재보궐선거      20130424   2013-04-24
# 27                 0            재보궐선거      20121219   2012-12-19
# 28                 0            재보궐선거      20120411   2012-04-11
# 29                 0            재보궐선거      20111026   2011-10-26
# 30                 0            재보궐선거      20110427   2011-04-27
# 31                 0            재보궐선거      20101027   2010-10-27
# 32                 0            재보궐선거      20100728   2010-07-28

# %% [markdown]
# # Step 1 - get sub election type

# %%
# Step 1 - get sub election type

url = "http://info.nec.go.kr/bizcommon/selectbox/selectbox_getSubElectionTypeJson.json"
electionId = "0000000000"
electionCode = ""
electionType = ""
dat_post = {'electionId': electionId, "electionCode": electionCode,"electionType":electionType}

# %%
bodyparts=[]

for index,row in dat_step0.iterrows():
    dat_post["electionCode"]=row["ElectionCode"]
    dat_post["electionType"]=row["ElectionTypeCode"]
    x = requests.post(url,data=dat_post)
    j = json.loads(x.text)
    body = j["jsonResult"]["body"]
    
    [bodyparts.append(list(row)+[item["CODE"],item["NAME"]]) for item in body]

# %%
dat_step1 = pd.DataFrame(bodyparts,columns=list(dat_step0.columns)+["SubElectionCode","SubElectionName"])
dat_step1
# Out:
#      ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 0                   1            대통령선거      20170509         제19대
# 1                   1            대통령선거      20121219         제18대
# 2                   1            대통령선거      20071219         제17대
# 3                   2           국회의원선거      20200415         제21대
# 4                   2           국회의원선거      20200415         제21대
# ..                ...              ...           ...          ...
# 108                 0            재보궐선거      20110427   2011-04-27
# 109                 0            재보궐선거      20101027   2010-10-27
# 110                 0            재보궐선거      20101027   2010-10-27
# 111                 0            재보궐선거      20101027   2010-10-27
# 112                 0            재보궐선거      20100728   2010-07-28
#
#      SubElectionCode SubElectionName
# 0                  1           대통령선거
# 1                  1           대통령선거
# 2                  1           대통령선거
# 3                  2          국회의원선거
# 4                  7      비례대표국회의원선거
# ..               ...             ...
# 108                6     구·시·군의회의원선거
# 109                4       구·시·군의장선거
# 110                5       시·도의회의원선거
# 111                6     구·시·군의회의원선거
# 112                2          국회의원선거
#
# [113 rows x 6 columns]

# %%
# save results from step 1
dat_step1.to_excel("../../data/2.0 current through 2022 data/2022 NEC web scraping/step 1 - get sub election/dat_step1.xlsx",index=False,encoding="utf-8")

# %% [markdown]
# # Step 2.1 - get city code for 재보궐선거

# %%
# Step 2 - city Code by Sg

# 재보궐선거
url = "http://info.nec.go.kr/bizcommon/selectbox/selectbox_cityCodeBySgJson_JAEBO_Old.json"
electionId = "0000000000"
subElectionCode = "" # get from the JSON response to Step 1
electionCode = ""   # same electionCode as in Step 1
dat_post = {'electionId': electionId, "subElectionCode": subElectionCode,"electionCode":electionCode}

# %%
dat_step2 = pd.DataFrame(columns=list(dat_step1.columns)+["CityCode","CityName"])
dat_step2
# Out:
# Empty DataFrame
# Columns: [ElectionTypeCode, ElectionTypeName, ElectionCode, ElectionName, SubElectionCode, SubElectionName, CityCode, CityName]
# Index: []

# %%
# 재보궐선거 from dat_step1  
dat_step1_subset = dat_step1[dat_step1["ElectionTypeCode"]==0]
dat_step1_subset.shape

# %%
dat_step1_subset
# Out:
#      ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 57                  0            재보궐선거      20210407   2021-04-07
# 58                  0            재보궐선거      20210407   2021-04-07
# 59                  0            재보궐선거      20210407   2021-04-07
# 60                  0            재보궐선거      20210407   2021-04-07
# 61                  0            재보궐선거      20200415   2020-04-15
# 62                  0            재보궐선거      20200415   2020-04-15
# 63                  0            재보궐선거      20200415   2020-04-15
# 64                  0            재보궐선거      20190403   2019-04-03
# 65                  0            재보궐선거      20190403   2019-04-03
# 66                  0            재보궐선거      20180613   2018-06-13
# 67                  0            재보궐선거      20170509   2017-05-09
# 68                  0            재보궐선거      20170509   2017-05-09
# 69                  0            재보궐선거      20170412   2017-04-12
# 70                  0            재보궐선거      20170412   2017-04-12
# 71                  0            재보궐선거      20170412   2017-04-12
# 72                  0            재보궐선거      20170412   2017-04-12
# 73                  0            재보궐선거      20160413   2016-04-13
# 74                  0            재보궐선거      20160413   2016-04-13
# 75                  0            재보궐선거      20160413   2016-04-13
# 76                  0            재보궐선거      20151028   2015-10-28
# 77                  0            재보궐선거      20151028   2015-10-28
# 78                  0            재보궐선거      20151028   2015-10-28
# 79                  0            재보궐선거      20150429   2015-04-29
# 80                  0            재보궐선거      20150429   2015-04-29
# 81                  0            재보궐선거      20150429   2015-04-29
# 82                  0            재보궐선거      20141029   2014-10-29
# 83                  0            재보궐선거      20140730   2014-07-30
# 84                  0            재보궐선거      20140730   2014-07-30
# 85                  0            재보궐선거      20131030   2013-10-30
# 86                  0            재보궐선거      20130424   2013-04-24
# 87                  0            재보궐선거      20130424   2013-04-24
# 88                  0            재보궐선거      20130424   2013-04-24
# 89                  0            재보궐선거      20130424   2013-04-24
# 90                  0            재보궐선거      20121219   2012-12-19
# 91                  0            재보궐선거      20121219   2012-12-19
# 92                  0            재보궐선거      20121219   2012-12-19
# 93                  0            재보궐선거      20121219   2012-12-19
# 94                  0            재보궐선거      20121219   2012-12-19
# 95                  0            재보궐선거      20120411   2012-04-11
# 96                  0            재보궐선거      20120411   2012-04-11
# 97                  0            재보궐선거      20120411   2012-04-11
# 98                  0            재보궐선거      20120411   2012-04-11
# 99                  0            재보궐선거      20120411   2012-04-11
# 100                 0            재보궐선거      20111026   2011-10-26
# 101                 0            재보궐선거      20111026   2011-10-26
# 102                 0            재보궐선거      20111026   2011-10-26
# 103                 0            재보궐선거      20111026   2011-10-26
# 104                 0            재보궐선거      20110427   2011-04-27
# 105                 0            재보궐선거      20110427   2011-04-27
# 106                 0            재보궐선거      20110427   2011-04-27
# 107                 0            재보궐선거      20110427   2011-04-27
# 108                 0            재보궐선거      20110427   2011-04-27
# 109                 0            재보궐선거      20101027   2010-10-27
# 110                 0            재보궐선거      20101027   2010-10-27
# 111                 0            재보궐선거      20101027   2010-10-27
# 112                 0            재보궐선거      20100728   2010-07-28
#
#      SubElectionCode SubElectionName
# 57                 3         시·도지사선거
# 58                 4      구·시·군의 장선거
# 59                 5       시·도의회의원선거
# 60                 6     구·시·군의회의원선거
# 61                 4      구·시·군의 장선거
# 62                 5       시·도의회의원선거
# 63                 6     구·시·군의회의원선거
# 64                 2          국회의원선거
# 65                 6     구·시·군의회의원선거
# 66                 2          국회의원선거
# 67                 5       시·도의회의원선거
# 68                 6     구·시·군의회의원선거
# 69                 2          국회의원선거
# 70                 4       구·시·군의장선거
# 71                 5       시·도의회의원선거
# 72                 6     구·시·군의회의원선거
# 73                 4       구·시·군의장선거
# 74                 5       시·도의회의원선거
# 75                 6     구·시·군의회의원선거
# 76                 4       구·시·군의장선거
# 77                 5       시·도의회의원선거
# 78                 6     구·시·군의회의원선거
# 79                 2          국회의원선거
# 80                 5       시·도의회의원선거
# 81                 6     구·시·군의회의원선거
# 82                 6     구·시·군의회의원선거
# 83                 2          국회의원선거
# 84                 6     구·시·군의회의원선거
# 85                 2          국회의원선거
# 86                 2          국회의원선거
# 87                 4       구·시·군의장선거
# 88                 5       시·도의회의원선거
# 89                 6     구·시·군의회의원선거
# 90                 3         시·도지사선거
# 91                11           교육감선거
# 92                 4       구·시·군의장선거
# 93                 5       시·도의회의원선거
# 94                 6     구·시·군의회의원선거
# 95                 3         시·도지사선거
# 96                11           교육감선거
# 97                 4       구·시·군의장선거
# 98                 5       시·도의회의원선거
# 99                 6     구·시·군의회의원선거
# 100                3         시·도지사선거
# 101                4       구·시·군의장선거
# 102                5       시·도의회의원선거
# 103                6     구·시·군의회의원선거
# 104                2          국회의원선거
# 105                3         시·도지사선거
# 106                4       구·시·군의장선거
# 107                5       시·도의회의원선거
# 108                6     구·시·군의회의원선거
# 109                4       구·시·군의장선거
# 110                5       시·도의회의원선거
# 111                6     구·시·군의회의원선거
# 112                2          국회의원선거

# %%
bodyparts=[]

for index,row in dat_step1_subset.iterrows():
    dat_post["subElectionCode"]=row["SubElectionCode"]
    dat_post["electionCode"]=row["ElectionCode"]
    x = requests.post(url,data=dat_post)
    j = json.loads(x.text)
    body = j["jsonResult"]["body"]
    
    [bodyparts.append(list(row)+[item["CODE"],item["NAME"]]) for item in body]

# %%
bodyparts
# Out:
# [[0, '재보궐선거', 20210407, '2021-04-07', 3, '시·도지사선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20210407, '2021-04-07',
거', 4500, '전라북도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 4, '구·시·군의장선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 2700, '대구광역시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 4500, '전라북도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 5, '시·도의회의원선거', 4900, '제주특별자치도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 2600, '부산광역시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 2700, '대구광역시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4300, '충청북도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4400, '충청남도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4500, '전라북도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4600, '전라남도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20160413, '2016-04-13', 6, '구·시·군의회의원선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 4, '구·시·군의장선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 5, '시·도의회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 5, '시·도의회의원선거', 2600, '부산광역시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 5, '시·도의회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 5, '시·도의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 5, '시·도의회의원선거', 4600, '전라남도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 2600, '부산광역시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 3100, '울산광역시'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 4200, '강원도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 4300, '충청북도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 4600, '전라남도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20151028, '2015-10-28', 6, '구·시·군의회의원선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 2, '국회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 2, '국회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 2, '국회의원선거', 2900, '광주광역시'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 2, '국회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 5, '시·도의회의원선거', 4200, '강원도'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 6, '구·시·군의회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 6, '구·시·군의회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 6, '구·시·군의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 6, '구·시·군의회의원선거', 4600, '전라남도'],
#  [0, '재보궐선거', 20150429, '2015-04-29', 6, '구·시·군의회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20141029, '2014-10-29', 6, '구·시·군의회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 2600, '부산광역시'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 2900, '광주광역시'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 3000, '대전광역시'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 3100, '울산광역시'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 4300, '충청북도'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 4400, '충청남도'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 2, '국회의원선거', 4600, '전라남도'],
#  [0, '재보궐선거', 20140730, '2014-07-30', 6, '구·시·군의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20131030, '2013-10-30', 2, '국회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20131030, '2013-10-30', 2, '국회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 2, '국회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 2, '국회의원선거', 2600, '부산광역시'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 2, '국회의원선거', 4400, '충청남도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 4, '구·시·군의장선거', 4100, '경기도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 4, '구·시·군의장선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 5, '시·도의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 5, '시·도의회의원선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 5, '시·도의회의원선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 6, '구·시·군의회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 6, '구·시·군의회의원선거', 4100, '경기도'],
#  [0, '재보궐선거', 20130424, '2013-04-24', 6, '구·시·군의회의원선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20121219, '2012-12-19', 3, '시·도지사선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20121219, '2012-12-19', 11, '교육감선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20121219, '2012-12-19', 4, '구·시·군의장선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20121219, '2012-12-19', 4, '구·시·군의장선거', 2900, '광주광역시'],
#  [0, '재보궐선거', 20121219, '2012-12-19', 4, '구·시·군의장선거', 4700, '경상북도'],
#  [0, '재보궐선거', 20121219, '2012-12-19',
거', 4800, '경상남도'],
#  [0, '재보궐선거', 20101027, '2010-10-27', 5, '시·도의회의원선거', 4800, '경상남도'],
#  [0, '재보궐선거', 20101027, '2010-10-27', 6, '구·시·군의회의원선거', 2600, '부산광역시'],
#  [0, '재보궐선거', 20101027, '2010-10-27', 6, '구·시·군의회의원선거', 4600, '전라남도'],
#  [0, '재보궐선거', 20100728, '2010-07-28', 2, '국회의원선거', 1100, '서울특별시'],
#  [0, '재보궐선거', 20100728, '2010-07-28', 2, '국회의원선거', 2800, '인천광역시'],
#  [0, '재보궐선거', 20100728, '2010-07-28', 2, '국회의원선거', 2900, '광주광역시'],
#  [0, '재보궐선거', 20100728, '2010-07-28', 2, '국회의원선거', 4200, '강원도'],
#  [0, '재보궐선거', 20100728, '2010-07-28', 2, '국회의원선거', 4300, '충청북도'],
#  [0, '재보궐선거', 20100728, '2010-07-28', 2, '국회의원선거', 4400, '충청남도']]

# %%
dat_step2_1 = pd.DataFrame(bodyparts,columns=dat_step2.columns)
dat_step2_1
# Out:
#      ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 0                   0            재보궐선거      20210407   2021-04-07
# 1                   0            재보궐선거      20210407   2021-04-07
# 2                   0            재보궐선거      20210407   2021-04-07
# 3                   0            재보궐선거      20210407   2021-04-07
# 4                   0            재보궐선거      20210407   2021-04-07
# ..                ...              ...           ...          ...
# 255                 0            재보궐선거      20100728   2010-07-28
# 256                 0            재보궐선거      20100728   2010-07-28
# 257                 0            재보궐선거      20100728   2010-07-28
# 258                 0            재보궐선거      20100728   2010-07-28
# 259                 0            재보궐선거      20100728   2010-07-28
#
#      SubElectionCode SubElectionName  CityCode CityName
# 0                  3         시·도지사선거      1100    서울특별시
# 1                  3         시·도지사선거      2600    부산광역시
# 2                  4      구·시·군의 장선거      3100    울산광역시
# 3                  4      구·시·군의 장선거      4800     경상남도
# 4                  5       시·도의회의원선거      1100    서울특별시
# ..               ...             ...       ...      ...
# 255                2          국회의원선거      2800    인천광역시
# 256                2          국회의원선거      2900    광주광역시
# 257                2          국회의원선거      4200      강원도
# 258                2          국회의원선거      4300     충청북도
# 259                2          국회의원선거      4400     충청남도
#
# [260 rows x 8 columns]

# %%
dat_step2_1.shape
# Out:
# (260, 8)

# %%
len(bodyparts)
# Out:
# 260

# %%
dat_step2_1.to_excel("../../data/2.0 current through 2022 data/2022 NEC web scraping/step 2 - get city/dat_step2_1.xlsx",index=False,encoding="utf-8")

# %% [markdown]
# # Step 2.2 - get city code for 지선 1-3

# %%
# 지선 1-3
http://info.nec.go.kr/bizcommon/selectbox/selectbox_cityCodeBySgJson_GuOld.json
electionId = "0000000000"
# subElectionCode = "" # sub election not required for old regional elections
electionCode = ""   # same electionCode as in Step 1
dat_post = {'electionId': electionId, "subElectionCode": subElectionCode,"electionCode":electionCode}

# %% [markdown]
# # Step 2.3 - get city code for everything else: 대선, 총선, 지선 > 3

# %%
# everything else: 대선, 총선, 지선 after #3
http://info.nec.go.kr/bizcommon/selectbox/selectbox_cityCodeBySgJson_Old.json
electionId = "0000000000"
subElectionCode = "" # get from the JSON response to Step 1
electionCode = ""   # same electionCode as in Step 1
dat_post = {'electionId': electionId, "subElectionCode": subElectionCode,"electionCode":electionCode}
