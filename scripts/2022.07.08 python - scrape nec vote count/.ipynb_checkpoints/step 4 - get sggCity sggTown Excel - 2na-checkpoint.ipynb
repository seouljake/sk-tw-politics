# %%
import winsound
frequency = 1000  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second

#winsound.Beep(frequency, duration)

def annoy(frequency,duration,n):
    for i in range(1, n):
        winsound.Beep(i * frequency, duration)
        
annoy(500,500,6)

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
import numpy as np
import lxml

# %% [markdown]
# # Step 4 - get sggCity, sggTown, and Excel - subelection 2 (국회의원선거)

# %% [markdown]
# ## Step 4.0 - choose subelection

# %%
subelection_code = 2
subelelection_name = "2na"

# %%
dat_step3 = pd.read_excel("../../data_electoral/2.0 current through 2022 data/2022 NEC web scraping/step 3 - get town/dat_step3.xlsx")

# %%
dat_step3[["SubElectionCode","SubElectionName"]].drop_duplicates().sort_values(by="SubElectionCode")
# Out:
#       SubElectionCode SubElectionName
# 4691                1           대통령선거
# 112                 2          국회의원선거
# 0                   3         시·도지사선거
# 41                  4      구·시·군의 장선거
# 140                 4       구·시·군의장선거
# 43                  5       시·도의회의원선거
# 51                  6     구·시·군의회의원선거
# 5690                7      비례대표국회의원선거
# 1518                8      광역의원비례대표선거
# 8686                9      기초의원비례대표선거
# 9183               10          교육의원선거
# 314                11           교육감선거

# %%
dat_step3
# Out:
#        ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 0                     0            재보궐선거      20210407   2021-04-07
# 1                     0            재보궐선거      20210407   2021-04-07
# 2                     0            재보궐선거      20210407   2021-04-07
# 3                     0            재보궐선거      20210407   2021-04-07
# 4                     0            재보궐선거      20210407   2021-04-07
# ...                 ...              ...           ...          ...
# 14408                 4             지방선거      20060531          제4회
# 14409                 4             지방선거      20060531          제4회
# 14410                 4             지방선거      20060531          제4회
# 14411                 4             지방선거      20060531          제4회
# 14412                 4             지방선거      20060531          제4회
#
#        SubElectionCode SubElectionName  CityCode CityName  TownCode TownName
# 0                    3         시·도지사선거      1100    서울특별시      1101      종로구
# 1                    3         시·도지사선거      1100    서울특별시      1102       중구
# 2                    3         시·도지사선거      1100    서울특별시      1103      용산구
# 3                    3         시·도지사선거      1100    서울특별시      1104      성동구
# 4                    3         시·도지사선거      1100    서울특별시      1105      광진구
# ...                ...             ...       ...      ...       ...      ...
# 14408                9      기초의원비례대표선거      4800     경상남도      4820      합천군
# 14409               10          교육의원선거      4900      제주도      4901      제주시
# 14410               10          교육의원선거      4900      제주도      4902     북제주군
# 14411               10          교육의원선거      4900      제주도      4903     서귀포시
# 14412               10          교육의원선거      4900      제주도      4904     남제주군
#
# [14413 rows x 10 columns]

# %% [markdown]
# ## Step 4.1 - get sggCityCode - for subelection = 1 (president), sggCityCode = NaN

# %% [markdown]
# ## Step 4.2 - get sggTownCode - for subelection = 1 (president), sggTownCode = NaN

# %%
dat_step4 = dat_step3[dat_step3["SubElectionCode"]==subelection_code]

# %%
dat_step4["SggCityCode"]=np.nan
dat_step4["SggCityName"]=np.nan
dat_step4["SggTownCode"]=np.nan
dat_step4["SggTownName"]=np.nan
# Out:
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\seoul\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
dat_step4
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 112                  0            재보궐선거      20190403   2019-04-03
# 113                  0            재보궐선거      20190403   2019-04-03
# 114                  0            재보궐선거      20190403   2019-04-03
# 117                  0            재보궐선거      20180613   2018-06-13
# 118                  0            재보궐선거      20180613   2018-06-13
# ...                ...              ...           ...          ...
# 7189                 2           국회의원선거      20080409         제18대
# 7190                 2           국회의원선거      20080409         제18대
# 7191                 2           국회의원선거      20080409         제18대
# 7192                 2           국회의원선거      20080409         제18대
# 7193                 2           국회의원선거      20080409         제18대
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName  \
# 112                 2          국회의원선거      4800     경상남도      4822   창원시성산구
# 113                 2          국회의원선거      4800     경상남도      4805      통영시
# 114                 2          국회의원선거      4800     경상남도      4806      고성군
# 117                 2          국회의원선거      1100    서울특별시      1111      노원구
# 118                 2          국회의원선거      1100    서울특별시      1124      송파구
# ...               ...             ...       ...      ...       ...      ...
# 7189                2          국회의원선거      4800     경상남도      4818      산청군
# 7190                2          국회의원선거      4800     경상남도      4819      거창군
# 7191                2          국회의원선거      4800     경상남도      4820      합천군
# 7192                2          국회의원선거      4900  제주특별자치도      4901      제주시
# 7193                2          국회의원선거      4900  제주특별자치도      4902     서귀포시
#
#       SggCityCode  SggCityName  SggTownCode  SggTownName
# 112           NaN          NaN          NaN          NaN
# 113           NaN          NaN          NaN          NaN
# 114           NaN          NaN          NaN          NaN
# 117           NaN          NaN          NaN          NaN
# 118           NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 7189          NaN          NaN          NaN          NaN
# 7190          NaN          NaN          NaN          NaN
# 7191          NaN          NaN          NaN          NaN
# 7192          NaN          NaN          NaN          NaN
# 7193          NaN          NaN          NaN          NaN
#
# [1072 rows x 14 columns]

# %%
dat_step4.shape
# Out:
# (1072, 14)

# %%
dat_step4.to_excel("../../data_electoral/2.0 current through 2022 data/2022 NEC web scraping/step 4 - get sggCity & sggTown/dat_step4_"+subelelection_name+".xlsx",index=False,encoding="utf-8")

# %% [markdown]
# ## Step 4.3 - download 개표현황(읍면동) Excel files

# %%
dat_step4 = pd.read_excel("../../data_electoral/2.0 current through 2022 data/2022 NEC web scraping/step 4 - get sggCity & sggTown/dat_step4_"+subelelection_name+".xlsx")

# %%
dat_step4
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 112                  0            재보궐선거      20190403   2019-04-03
# 113                  0            재보궐선거      20190403   2019-04-03
# 114                  0            재보궐선거      20190403   2019-04-03
# 117                  0            재보궐선거      20180613   2018-06-13
# 118                  0            재보궐선거      20180613   2018-06-13
# ...                ...              ...           ...          ...
# 7189                 2           국회의원선거      20080409         제18대
# 7190                 2           국회의원선거      20080409         제18대
# 7191                 2           국회의원선거      20080409         제18대
# 7192                 2           국회의원선거      20080409         제18대
# 7193                 2           국회의원선거      20080409         제18대
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName  \
# 112                 2          국회의원선거      4800     경상남도      4822   창원시성산구
# 113                 2          국회의원선거      4800     경상남도      4805      통영시
# 114                 2          국회의원선거      4800     경상남도      4806      고성군
# 117                 2          국회의원선거      1100    서울특별시      1111      노원구
# 118                 2          국회의원선거      1100    서울특별시      1124      송파구
# ...               ...             ...       ...      ...       ...      ...
# 7189                2          국회의원선거      4800     경상남도      4818      산청군
# 7190                2          국회의원선거      4800     경상남도      4819      거창군
# 7191                2          국회의원선거      4800     경상남도      4820      합천군
# 7192                2          국회의원선거      4900  제주특별자치도      4901      제주시
# 7193                2          국회의원선거      4900  제주특별자치도      4902     서귀포시
#
#       SggCityCode  SggCityName  SggTownCode  SggTownName
# 112           NaN          NaN          NaN          NaN
# 113           NaN          NaN          NaN          NaN
# 114           NaN          NaN          NaN          NaN
# 117           NaN          NaN          NaN          NaN
# 118           NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 7189          NaN          NaN          NaN          NaN
# 7190          NaN          NaN          NaN          NaN
# 7191          NaN          NaN          NaN          NaN
# 7192          NaN          NaN          NaN          NaN
# 7193          NaN          NaN          NaN          NaN
#
# [1072 rows x 14 columns]

# %%
# query electionInfo page - for subelection = 1 (president)

url = "http://info.nec.go.kr/electioninfo/electionInfo_report.xhtml"

electionId = "0000000000"
requestURI = "/WEB-INF/jsp/electioninfo/0000000000/vc/vccp04.jsp"
topMenuId = "VC"
secondMenuId = "VCCP04"
menuId = "VCCP04"
statementId = "VCCP04_#2"
oldElectionType = "1"
electionType = "2"         # ElectionTypeCode - variable - 재보궐 = 0, 총선 = 2, 
electionName = "20170509"  # ElectionCode - variable
electionCode = "2"         # SubElectionCode - fixed - 국회의원선거 = 2
cityCode = "2600"          # CityCode - variable
sggCityCode = "-1"         # SggCityCode - NaN
townCodeFromSgg = "-1"     # SggTownCode - NaN
townCode = "2604"          # TownCode - variable
#sggTownCode = ""          # SGGTownCode - not a parameter
x = "38"
y = "18"

dat_post = {'electionId': electionId,
            "requestURI": requestURI,
            "topMenuId": topMenuId,
            "secondMenuId": secondMenuId,
            "menuId":menuId,
            "statementId":statementId,
            "oldElectionType":oldElectionType,
            "electionType":electionType,       # ElectionTypeCode - variable
            "electionName":electionName,       # ElectionCode - variable  
            "electionCode":electionCode,       # SubElectionCode - fixed
            "cityCode":cityCode,               # CityCode - variable
            "sggCityCode":sggCityCode,         # SggCityCode - fixed
            "townCodeFromSgg":townCodeFromSgg, # TownCode - fixed
            "townCode":townCode,               # TownCode - variable
            #"sggTownCode":"",                 # SggTownCode - omitted from subelection = 1 (president)
            "x":x,
            "y":y}

# %%
## test requests
d = dat_step4
# d = dat_step3[dat_step3["ElectionTypeCode"]==4]
# d = d[d["ElectionCode"]>=20060531]
# d

# %%
excelpath = "../../data_electoral/2.0 current through 2022 data/2022 NEC web scraping/step 4 - get sggCity & sggTown/votecount_"+subelelection_name+"/"

# %%
for index,row in d[1000:1075].iterrows():
    
    # post parameters for subelection = 1 (president)
    dat_post["electionType"]=row["ElectionTypeCode"]
    dat_post["electionName"]=row["ElectionCode"]
    #dat_post["electionCode"]=row["SubElectionCode"]
    dat_post["cityCode"]=row["CityCode"]
    #dat_post["sggCityCode"]=row["SggCityCode"]
    #dat_post["townCodeFromSgg"]=row["TownCode"]
    dat_post["townCode"]=row["TownCode"]
    #dat_post["sggTownCode"]=row["SggTownCode"]
                
    x = requests.post(url,data=dat_post)
    #print(row)
    print(index,row["ElectionTypeName"],row["ElectionName"],row["ElectionCode"],row["CityCode"],row["CityName"],row["TownCode"],row["TownName"],x.status_code)

    #j = json.loads(x.text)
    
    # write html file
    # fo = open("out.html", "w",encoding="utf-8")
    # fo.write(x.text)
    # fo.close()
    

    # convert html table to pandas and write as an excel file
    tables = pd.read_html(x.text)
    t = tables[0]
    
    excelfilename = "votecount_"+subelelection_name+"_"+str(row["ElectionCode"])+"_"+str(row["CityCode"])+"_"+str(row["TownCode"])+".xlsx"

    t.to_excel(excelpath+excelfilename)

    
annoy(500,500,6)
# Out:
# 7122 국회의원선거 제18대 20080409 4500 전라북도 4514 임실군 200
# 7123 국회의원선거 제18대 20080409 4500 전라북도 4515 순창군 200
# 7124 국회의원선거 제18대 20080409 4500 전라북도 4516 고창군 200
# 7125 국회의원선거 제18대 20080409 4500 전라북도 4517 부안군 200
# 7126 국회의원선거 제18대 20080409 4600 전라남도 4601 목포시 200
# 7127 국회의원선거 제18대 20080409 4600 전라남도 4602 여수시 200
# 7128 국회의원선거 제18대 20080409 4600 전라남도 4604 순천시 200
# 7129 국회의원선거 제18대 20080409 4600 전라남도 4606 나주시 200
# 7130 국회의원선거 제18대 20080409 4600 전라남도 4607 광양시 200
# 7131 국회의원선거 제18대 20080409 4600 전라남도 4608 담양군 200
# 7132 국회의원선거 제18대 20080409 4600 전라남도 4609 장성군 200
# 7133 국회의원선거 제18대 20080409 4600 전라남도 4610 곡성군 200
# 7134 국회의원선거 제18대 20080409 4600 전라남도 4611 구례군 200
# 7135 국회의원선거 제18대 20080409 4600 전라남도 4612 고흥군 200
# 7136 국회의원선거 제18대 20080409 4600 전라남도 4613 보성군 200
# 7137 국회의원선거 제18대 20080409 4600 전라남도 4614 화순군 200
# 7138 국회의원선거 제18대 20080409 4600 전라남도 4615 장흥군 200
# 7139 국회의원선거 제18대 20080409 4600 전라남도 4616 강진군 200
# 7140 국회의원선거 제18대 20080409 4600 전라남도 4617 완도군 200
# 7141 국회의원선거 제18대 20080409 4600 전라남도 4618 해남군 200
# 7142 국회의원선거 제18대 20080409 4600 전라남도 4619 진도군 200
# 7143 국회의원선거 제18대 20080409 4600 전라남도 4620 영암군 200
# 7144 국회의원선거 제18대 20080409 4600 전라남도 4621 무안군 200
# 7145 국회의원선거 제18대 20080409 4600 전라남도 4622 영광군 200
# 7146 국회의원선거 제18대 20080409 4600 전라남도 4623 함평군 200
# 7147 국회의원선거 제18대 20080409 4600 전라남도 4624 신안군 200
# 7148 국회의원선거 제18대 20080409 4700 경상북도 4701 포항시북구 200
# 7149 국회의원선거 제18대 20080409 4700 경상북도 4702 포항시남구 200
# 7150 국회의원선거 제18대 20080409 4700 경상북도 4703 울릉군 200
# 7151 국회의원선거 제18대 20080409 4700 경상북도 4704 경주시 200
# 7152 국회의원선거 제18대 20080409 4700 경상북도 4705 김천시 200
# 7153 국회의원선거 제18대 20080409 4700 경상북도 4706 안동시 200
# 7154 국회의원선거 제18대 20080409 4700 경상북도 4707 구미시 200
# 7155 국회의원선거 제18대 20080409 4700 경상북도 4708 영주시 200
# 7156 국회의원선거 제18대 20080409 4700 경상북도 4709 영천시 200
# 7157 국회의원선거 제18대 20080409 4700 경상북도 4710 상주시 200
# 7158 국회의원선거 제18대 20080409 4700 경상북도 4711 문경시 200
# 7159 국회의원선거 제18대 20080409 4700 경상북도 4712 예천군 200
# 7160 국회의원선거 제18대 20080409 4700 경상북도 4713 경산시 200
# 7161 국회의원선거 제18대 20080409 4700 경상북도 4714 청도군 200
# 7162 국회의원선거 제18대 20080409 4700 경상북도 4715 고령군 200
# 7163 국회의원선거 제18대 20080409 4700 경상북도 4716 성주군 200
# 7164 국회의원선거 제18대 20080409 4700 경상북도 4717 칠곡군 200
# 7165 국회의원선거 제18대 20080409 4700 경상북도 4718 군위군 200
# 7166 국회의원선거 제18대 20080409 4700 경상북도 4719 의성군 200
# 7167 국회의원선거 제18대 20080409 4700 경상북도 4720 청송군 200
# 7168 국회의원선거 제18대 20080409 4700 경상북도 4721 영양군 200
# 7169 국회의원선거 제18대 20080409 4700 경상북도 4722 영덕군 200
# 7170 국회의원선거 제18대 20080409 4700 경상북도 4723 봉화군 200
# 7171 국회의원선거 제18대 20080409 4700 경상북도 4724 울진군 200
# 7172 국회의원선거 제18대 20080409 4800 경상남도 4801 창원시 200
# 7173 국회의원선거 제18대 20080409 4800 경상남도 4802 마산시 200
# 7174 국회의원선거 제18대 20080409 4800 경상남도 4803 진주시 200
# 7175 국회의원선거 제18대 20080409 4800 경상남도 4804 진해시 200
# 7176 국회의원선거 제18대 20080409 4800 경상남도 4805 통영시 200
# 7177 국회의원선거 제18대 20080409 4800 경상남도 4806 고성군 200
# 7178 국회의원선거 제18대 20080409 4800 경상남도 4807 사천시 200
# 7179 국회의원선거 제18대 20080409 4800 경상남도 4808 김해시 200
# 7180 국회의원선거 제18대 20080409 4800 경상남도 4809 밀양시 200
# 7181 국회의원선거 제18대 20080409 4800 경상남도 4810 거제시 200
# 7182 국회의원선거 제18대 20080409 4800 경상남도 4811 의령군 200
# 7183 국회의원선거 제18대 20080409 4800 경상남도 4812 함안군 200
# 7184 국회의원선거 제18대 20080409 4800 경상남도 4813 창녕군 200
# 7185 국회의원선거 제18대 20080409 4800 경상남도 4814 양산시 200
# 7186 국회의원선거 제18대 20080409 4800 경상남도 4815 하동군 200
# 7187 국회의원선거 제18대 20080409 4800 경상남도 4816 남해군 200
# 7188 국회의원선거 제18대 20080409 4800 경상남도 4817 함양군 200
# 7189 국회의원선거 제18대 20080409 4800 경상남도 4818 산청군 200
# 7190 국회의원선거 제18대 20080409 4800 경상남도 4819 거창군 200
# 7191 국회의원선거 제18대 20080409 4800 경상남도 4820 합천군 200
# 7192 국회의원선거 제18대 20080409 4900 제주특별자치도 4901 제주시 200
# 7193 국회의원선거 제18대 20080409 4900 제주특별자치도 4902 서귀포시 200

# %%
# print out last item as an html file
# fo = open("out.html", "w",encoding="utf-8")
# fo.write(x.text)
# fo.close()

# %%
d
# Out:
#       ElectionTypeCode ElectionTypeName  ElectionCode ElectionName  \
# 112                  0            재보궐선거      20190403   2019-04-03
# 113                  0            재보궐선거      20190403   2019-04-03
# 114                  0            재보궐선거      20190403   2019-04-03
# 117                  0            재보궐선거      20180613   2018-06-13
# 118                  0            재보궐선거      20180613   2018-06-13
# ...                ...              ...           ...          ...
# 7189                 2           국회의원선거      20080409         제18대
# 7190                 2           국회의원선거      20080409         제18대
# 7191                 2           국회의원선거      20080409         제18대
# 7192                 2           국회의원선거      20080409         제18대
# 7193                 2           국회의원선거      20080409         제18대
#
#       SubElectionCode SubElectionName  CityCode CityName  TownCode TownName  \
# 112                 2          국회의원선거      4800     경상남도      4822   창원시성산구
# 113                 2          국회의원선거      4800     경상남도      4805      통영시
# 114                 2          국회의원선거      4800     경상남도      4806      고성군
# 117                 2          국회의원선거      1100    서울특별시      1111      노원구
# 118                 2          국회의원선거      1100    서울특별시      1124      송파구
# ...               ...             ...       ...      ...       ...      ...
# 7189                2          국회의원선거      4800     경상남도      4818      산청군
# 7190                2          국회의원선거      4800     경상남도      4819      거창군
# 7191                2          국회의원선거      4800     경상남도      4820      합천군
# 7192                2          국회의원선거      4900  제주특별자치도      4901      제주시
# 7193                2          국회의원선거      4900  제주특별자치도      4902     서귀포시
#
#       SggCityCode  SggCityName  SggTownCode  SggTownName
# 112           NaN          NaN          NaN          NaN
# 113           NaN          NaN          NaN          NaN
# 114           NaN          NaN          NaN          NaN
# 117           NaN          NaN          NaN          NaN
# 118           NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 7189          NaN          NaN          NaN          NaN
# 7190          NaN          NaN          NaN          NaN
# 7191          NaN          NaN          NaN          NaN
# 7192          NaN          NaN          NaN          NaN
# 7193          NaN          NaN          NaN          NaN
#
# [1072 rows x 14 columns]

# %% [markdown]
# ## Step 4.4 - stats

# %%
d.groupby(["ElectionTypeCode"]).agg({"TownCode":"count"})
# Out:
#                   TownCode
# ElectionTypeCode
# 0                       71
# 2                     1001

# %%
d.groupby(["ElectionTypeCode","SubElectionCode"]).agg({"TownCode":"count"})
# Out:
#                                   TownCode
# ElectionTypeCode SubElectionCode
# 0                2                      71
# 2                2                    1001

# %%
d.groupby(["ElectionTypeCode","ElectionCode","SubElectionCode"]).agg({"TownCode":"count"})
# Out:
#                                                TownCode
# ElectionTypeCode ElectionCode SubElectionCode
# 0                20100728     2                      14
#                  20110427     2                       3
#                  20130424     2                       4
#                  20131030     2                       3
#                  20140730     2                      21
#                  20150429     2                       4
#                  20170412     2                       4
#                  20180613     2                      15
#                  20190403     2                       3
# 2                20080409     2                     248
#                  20120411     2                     251
#                  20160413     2                     252
#                  20200415     2                     250

# %%
d.groupby(["ElectionTypeCode","ElectionCode","SubElectionCode"]).agg({"CityCode":"nunique"})
# Out:
#                                                CityCode
# ElectionTypeCode ElectionCode SubElectionCode
# 0                20100728     2                       6
#                  20110427     2                       3
#                  20130424     2                       3
#                  20131030     2                       2
#                  20140730     2                       9
#                  20150429     2                       4
#                  20170412     2                       1
#                  20180613     2                      10
#                  20190403     2                       1
# 2                20080409     2                      16
#                  20120411     2                      17
#                  20160413     2                      17
#                  20200415     2                      17
